# %%
import pandas as pd
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score, davies_bouldin_score

# %%
data=pd.read_csv(r"C:\Users\ishan\Desktop\machine learning\government_complaint_management\for_model.csv")

# %%
for i in data["Complaint"]:
    print(i)
# Out:
# There is an ongoing robbery at my house, please send help immediately!
# I just witnessed a kidnapping near the central park!
# A serious accident just happened, and people are injured.
# A gang fight is happening near my street, they have weapons.
# My house is on fire, I need emergency services now!
# There is an active shooter situation in the mall, please respond urgently!
# My child is missing, last seen near the school playground.
# An elderly person has collapsed on the road and is unresponsive.
# There is a man harassing and threatening people with a knife at the subway.
# A woman is screaming for help in my neighborhood, I fear domestic violence.
# There is a suspicious vehicle parked outside my house for hours.
# My neighbor keeps playing loud music late at night, disturbing everyone.
# I lost my phone at the metro station, can it be tracked?
# I suspect someone is dealing drugs near the community park.
# There is an abandoned bag at the train station, it looks suspicious.
# I have been receiving scam calls claiming to be from the police department.
# A street light has been broken for weeks, making it unsafe at night.
# I found a wallet on the street and want to return it to the owner.
# Someone scratched my car in the parking lot and left without informing.
# A stray dog is acting aggressively in our neighborhood, it might bite someone.
# Someone is blocking my driveway with their vehicle.
# A shopkeeper is overcharging customers and refusing to give receipts.
# People are spitting in public places despite the ban.
# There are potholes on the main road causing minor accidents.
# A street vendor is operating without a license in front of my shop.
# Someone keeps throwing garbage in front of my house every night.
# The local park is not being maintained properly, it's full of litter.
# A few kids are bursting crackers at odd hours, disturbing residents.
# People are feeding pigeons on my balcony, creating a mess.
# Some bikers are performing stunts on the road, causing inconvenience.
# A car is parked in a no-parking zone, blocking the entrance to my building.
# There is a water leakage on the main road causing traffic congestion.
# A street performer is creating a nuisance with loudspeakers near the market.
# A person is selling cigarettes to minors outside the school gate.
# Some miscreants are damaging public property in the subway station.
# Someone has vandalized my shop by spray painting on the walls.
# A cyclist was hit by a speeding car, but the driver fled the scene.
# A group of teenagers is drinking alcohol in the public park.
# There is a snake in my backyard, I need animal control support.
# I have lost my passport while traveling, need help to report it.
# A streetlight has been flickering, making it unsafe for pedestrians at night.
# My landlord is harassing me and refusing to return my deposit.
# I received a fake currency note from a shop, I need to report it.
# A delivery agent misbehaved with me and refused to deliver my package.
# There is a major traffic jam due to an overturned truck on the highway.
# Some strangers are constantly loitering near my house, it seems suspicious.
# My colleague is threatening me at work, I fear for my safety.
# An ATM in our area has been broken into, I suspect theft.
# A group of people are gambling in an open area near my house.
# Some people are illegally cutting trees in the community park.
# I saw someone trying to break into a parked car last night.
# There is a dead animal on the road causing a foul smell and hygiene issues.
# A wedding procession is blocking the road, causing heavy traffic.
# My bike was stolen from the parking lot, I need to report it.
# My credit card details have been stolen and unauthorized transactions were made.
# A group of people are blocking the road to protest without permission.
# My friend has gone missing, last seen near the railway station.
# An unknown number has been calling and threatening me repeatedly.
# There is a chemical spill near the factory, causing a hazardous situation.
# A reckless driver almost hit pedestrians near the school zone.
# My domestic helper has suddenly disappeared, and I cannot contact them.
# Some people are selling illegal firecrackers outside the temple area.
# A man is attempting to break into a locked car in the parking lot.
# There are illegal hoardings blocking visibility at intersections.
# A beggar is harassing commuters at the bus stop for money.
# I suspect my tenant is running an illegal business in my house.
# There is a power outage in our street, and thieves might take advantage.
# A vehicle with tinted windows is moving suspiciously around my area.
# Some children are climbing an under-construction building, it’s unsafe.
# A local vendor is dumping garbage into the nearby lake.
# My neighbor’s pet keeps trespassing into my property and causing damage.
# A firecracker store has caught fire, spreading smoke in the area.
# I saw someone pickpocketing in the crowded train station.
# A man is behaving indecently towards women in the metro.
# Some individuals are selling expired food products in the supermarket.
# A man is following me continuously, I feel unsafe.
# A package was stolen from my doorstep while I was away.
# There is a large pothole on the highway causing accidents.
# Someone has been ringing my doorbell at odd hours and running away.
# The drainage system is overflowing and flooding the streets.
# My house keys were stolen along with my bag, I need assistance.
# There is illegal sand mining happening near the riverbed at night.
# A truck is over-speeding in a residential area, risking lives.
# A person is smoking inside a hospital despite warnings.
# A neighbor has been burning trash, causing smoke pollution.
# The bus drivers are refusing to stop at designated stops.
# I found counterfeit notes in the cash given to me at a shop.
# A security guard at a shopping mall misbehaved with customers.
# A group of men are trespassing into private property near my house.
# A tourist got lost in the jungle trek and hasn't returned.
# There are reports of illegal arms trading near the border.
# My relative was taken to the hospital after a hit-and-run case.
# A domestic servant has been physically abused by their employer.
# Someone left an unidentified package in our apartment lobby.
# A drone has been flying over my house repeatedly, it seems suspicious.
# Someone hacked my bank account and transferred all my money.
# I am receiving death threats from an unknown person via email.
# My social media account has been hacked, and the hacker is posting illegal content.
# A cybercriminal is blackmailing me with my private photos.
# There is a major data breach at my company, and sensitive data is leaked.
# I just received an email with ransomware, and my files are locked.
# My child's online gaming account has been compromised, and the hacker is demanding money.
# I was tricked into installing malware, and now my device is locked.
# A hacker gained access to my cloud storage and deleted all my files.
# Someone created a fake profile using my identity and is scamming people.
# I received an email threatening to expose my personal data unless I pay ransom.
# My company's confidential data has been leaked on the dark web.
# Hackers have taken control of my business website and are demanding money.
# I accidentally clicked on a fake PayPal link, and now my account is compromised.
# A hacker is using my email to send phishing links to my contacts.
# Someone gained unauthorized access to my medical records.
# Hackers have accessed my webcam and are recording without my knowledge.
# I received an extortion email claiming to have access to my browsing history.
# My cryptocurrency wallet was hacked, and all my funds are stolen.
# A fraudulent loan was taken in my name using stolen credentials.
# I received a phishing email pretending to be from my bank.
# A fake e-commerce website scammed me and never delivered my order.
# Someone is impersonating me on social media and messaging my friends.
# I accidentally downloaded a suspicious file, and now my computer is slow.
# There is a fraudulent investment scheme being advertised online.
# My credit card details were stolen, and unauthorized transactions were made.
# I keep receiving scam calls asking for my OTP.
# A hacker tried to access my email, but I was able to reset the password.
# A stranger keeps sending me inappropriate messages on social media.
# Someone is using my WiFi network without permission.
# A social media influencer is promoting a fraudulent crypto investment scheme.
# A scammer tricked me into sharing my banking details over a call.
# I lost money in an online job scam that asked for an advance fee.
# Someone created a deepfake video of me and shared it online.
# I keep getting fake invoices from unknown companies via email.
# My online gaming account was hacked, and all my in-game purchases are gone.
# A fraudster is running a fake giveaway to collect personal details.
# An unknown device was logged into my email without my knowledge.
# A scammer created a fake online dating profile and tricked me into sending money.
# A software I installed is collecting my personal data without consent.
# Someone stole my domain name and is using it for fraudulent activities.
# A customer left a false online review about my business to damage my reputation.
# A bot is continuously spamming my blog with fake comments.
# Someone is running a lottery scam using my name and photos.
# I found a website selling my personal information.
# I keep getting random video calls from strangers on messaging apps.
# A fake charity website is scamming people in the name of donations.
# A hacker has been accessing my work emails without authorization.
# There is an increase in fake tech support calls in my area.
# I received an email pretending to be from the police department asking for money.
# A fraudulent online training program is collecting personal information.
# I noticed someone is trying to access my Netflix and other streaming accounts.
# A fake travel agency scammed me with non-existent vacation packages.
# A bot network is launching DDoS attacks on my business website.
# An influencer is running a scam contest with no real prizes.
# A fake job recruiter asked me to pay for training materials.
# A scammer tried to register my phone number under a different telecom provider.
# I keep getting spam emails despite blocking the sender.
# My old social media account was hacked, but I no longer use it.
# I got a pop-up saying I won a lottery, but I didn't click on it.
# There is an ad blocker that isn’t working properly on my browser.
# My online review about a company was deleted without reason.
# I suspect someone is using AI to generate fake images of me.
# I received a promotional email from an unknown sender.
# An app I downloaded is asking for unnecessary permissions.
# Someone created a meme using my photo without consent.
# I keep getting fake friend requests from unknown people.
# Someone used my email to sign up for multiple random websites.
# I keep seeing fake product reviews on online shopping sites.
# A website keeps auto-subscribing me to its newsletter.
# Someone is using my profile picture without my permission.
# I am receiving too many pop-up ads on my mobile browser.
# A website asked me to disable my antivirus before downloading software.
# A chatbot on a website is giving misleading information.
# A social media platform is not allowing me to delete my old posts.
# A gaming forum banned me without a valid reason.
# I noticed that my social media feed is showing too many ads.
# My email provider is marking legitimate emails as spam.
# I received a fake job offer through LinkedIn.
# An app I installed is draining my phone battery abnormally fast.
# I saw a website selling fake brand-name clothing items.
# Someone is copying my tweets and reposting them as their own.
# My online banking app logs me out frequently without reason.
# I saw a scammer advertising fake digital marketing services.
# My mobile banking app is showing incorrect transaction history.
# A weather app I installed is tracking my location unnecessarily.
# A website I visited recently is now sending me excessive notifications.
# I am facing domestic violence, and my life is in danger.
# I was sexually harassed while traveling alone at night.
# A man is stalking me every day near my house.
# I have received rape threats on social media.
# I was physically assaulted by my in-laws over dowry demands.
# My husband is threatening to kill me if I report domestic abuse.
# I was drugged and harassed at a party.
# A stranger is following me and trying to force me into his car.
# A gang of men has been harassing girls near our college campus.
# I was forcibly taken to an unknown location and held against my will.
# I am a minor, and my parents are trying to force me into marriage.
# My partner has locked me inside the house and is refusing to let me leave.
# I saw a girl being forcefully dragged into a car by a group of men.
# I was groped in a crowded public place, and no one helped.
# Someone has been blackmailing me with private pictures.
# A local goon is harassing girls and threatening them with acid attacks.
# My employer is demanding sexual favors in return for my salary.
# A group of men is harassing me and my female colleagues daily.
# I found a hidden camera in my hotel room.
# A stranger forcibly entered my house and tried to assault me.
# My husband refuses to give me financial support for my children.
# My landlord is making inappropriate advances toward me.
# My in-laws are mentally torturing me because I gave birth to a girl.
# My ex-boyfriend is sharing false rumors about me online.
# I was denied a job because I am a woman.
# A shopkeeper harassed me when I went shopping alone.
# A man keeps sending me inappropriate messages despite blocking him.
# A colleague keeps invading my personal space at work.
# I am facing constant pressure from my family to quit my job.
# My brother controls all my financial transactions and won’t let me be independent.
# A man is sending me continuous messages despite my warnings.
# My husband is secretly recording my phone conversations.
# My co-worker keeps making sexist jokes and comments.
# A man tried to take pictures of me without my consent in public.
# A stranger is making obscene gestures at me every morning.
# A group of boys in my neighborhood teases girls who pass by.
# My friend was abandoned by her husband, and he refuses to take responsibility.
# A social media account is posting edited pictures of me.
# A man threatened to throw acid on me after I rejected his proposal.
# My boss keeps making inappropriate remarks about my appearance.
# My husband’s family is trying to take away my children from me.
# I am being forced to quit my studies because I am a girl.
# A boy keeps spreading rumors about me at my college.
# My workplace does not have any complaint mechanism for sexual harassment.
# My housemaid is being physically abused by her employer.
# I am being body-shamed by my relatives, causing mental distress.
# A professor is offering good grades in exchange for favors.
# A fake marriage proposal was used to scam me and take my money.
# My daughter’s teacher is behaving inappropriately with her.
# I was touched inappropriately by a stranger in public transport.
# A colleague keeps forcing me to go out with him despite my refusals.
# My landlord refuses to rent an apartment to me because I am a single woman.
# A man is stalking me on different social media platforms.
# A family is forcefully keeping their daughter-in-law locked at home.
# My fiancé broke off our engagement and is refusing to return my belongings.
# My friend is being emotionally blackmailed into staying in a toxic relationship.
# I am constantly harassed by boys in my coaching institute.
# My husband took a huge loan in my name without my consent.
# A man keeps staring at me in public places, making me uncomfortable.
# I keep receiving fake marriage proposals from unknown people.
# My husband doesn’t help with household chores despite both of us working.
# A co-worker makes fun of working mothers in the office.
# My parents don’t allow me to have male friends.
# A neighborhood boy keeps whistling at girls when they pass by.
# I feel unsafe walking alone at night due to lack of streetlights.
# I faced gender discrimination at a restaurant when dining alone.
# My boss refused to approve my maternity leave.
# I am not allowed to go out alone due to my family's conservative mindset.
# My family prefers my brother over me for educational opportunities.
# A man keeps catcalling me every time I walk past his shop.
# My friends often dismiss my safety concerns as overreacting.
# A street vendor tried to flirt with me while I was shopping.
# My school does not have proper sanitary facilities for girls.
# A distant relative keeps making uncomfortable comments about my appearance.
# A group of boys keeps following me and my friends after school.
# My apartment complex does not allow single women to rent apartments.
# My cousin's husband often comments on how women should stay at home.
# A boy in my class keeps asking me personal questions despite my refusals.
# My neighborhood does not feel safe due to lack of police patrols.
# A female colleague was denied a promotion despite being more qualified.
# I was forced to wear traditional clothes to a family gathering.
# My male relatives control all family decisions, ignoring female opinions.
# A male passenger refused to let me sit in a reserved women's seat on a bus.
# My parents refused to let me take up a job because of societal pressure.
# A customer at my workplace keeps making sexist comments.
# A group of men often block the way near my college to harass girls.
# A boy in my tuition center keeps calling me names.
# My friend was asked inappropriate questions during a job interview.
# A major fire has broken out in our apartment complex, and people are trapped inside.
# A factory near my house has caught fire, and explosions are occurring.
# A gas cylinder exploded in our neighborhood, and the fire is spreading fast.
# A car caught fire in a busy market area, and people are panicking.
# A fire broke out in a school building with students still inside.
# A high-rise building is on fire, and people are stranded on the top floors.
# There is a huge fire in a hospital, and patients need immediate evacuation.
# A petrol pump has caught fire, and it is spreading rapidly.
# An electric short circuit has caused a fire in our office building.
# A slum area has caught fire, and many families are at risk.
# A bus full of passengers has caught fire on the highway.
# A chemical factory explosion has triggered a large-scale fire.
# A forest fire is approaching residential areas.
# A train compartment has caught fire while traveling.
# A warehouse storing flammable materials is burning.
# There is a fire at an LPG storage facility.
# A house in our colony caught fire due to a gas leak.
# An oil tanker overturned and caught fire on the main road.
# An industrial unit dealing with hazardous chemicals is burning.
# A restaurant kitchen fire has gone out of control.
# There is a burning smell and smoke coming from an electrical transformer.
# A shop in the market has caught fire, but no one is trapped inside.
# A fire broke out in a garbage dump, and the smoke is unbearable.
# A tree caught fire due to a short circuit in the electrical wires.
# A minor fire broke out in an ATM cabin.
# A truck carrying chemicals is emitting smoke.
# A small fire started in a parked vehicle.
# There was a fire in a godown, but it has been partially controlled.
# A small explosion in a factory has caused a fire hazard.
# The air conditioning unit in our office has started emitting smoke.
# A mobile tower caught fire after a thunderstorm.
# Sparks from welding work ignited a minor fire at a construction site.
# A power line fell and started a small fire in a residential area.
# A bonfire at a public event got out of control.
# A bakery caught fire due to an overheated oven.
# A fire started in a temple due to unattended oil lamps.
# An unattended stove led to a minor kitchen fire.
# Firecrackers ignited a small fire in an empty lot.
# A generator caught fire due to overheating.
# A tent at a wedding function caught fire.
# A temporary festival stall caught fire from a nearby lamp.
# A bank's UPS room is emitting excessive heat and smoke.
# An elevator machine room caught fire due to overheating.
# A small explosion in a petrol station caused a minor fire.
# A battery storage facility has started emitting smoke.
# A firework manufacturing unit had a minor fire incident.
# A drone battery exploded and started a small fire.
# A restaurant's chimney caught fire due to excessive grease buildup.
# A fire was noticed inside a mall’s food court kitchen.
# A laundromat dryer overheated and caught fire.
# A home inverter battery exploded, causing a small fire.
# An illegal LPG refill center caught fire.
# A hotel room caught fire due to an unattended iron.
# A cotton warehouse caught fire from a spark.
# A cinema hall projection room had a fire incident.
# A scrap yard fire is creating dense smoke.
# A fire in a car repair workshop has spread to nearby vehicles.
# A wooden furniture shop caught fire from a welding spark.
# People are burning dry leaves in our neighborhood, creating smoke.
# Someone is lighting fireworks in a restricted area.
# A local factory is emitting smoke, which seems suspicious.
# Someone is burning trash in an open field.
# A street vendor is using an illegal gas cylinder.
# The fire extinguisher in our office is empty.
# A chimney in a bakery is emitting excessive smoke.
# A transformer in our street is making a crackling noise.
# A barbecue in a park has been left unattended.
# Sparks were noticed coming from a street lamp post.
# A garbage pile near our house is smoldering.
# A festival decoration caught fire but was immediately put out.
# A car’s exhaust pipe emitted flames momentarily.
# Someone is using high-voltage electrical appliances without safety precautions.
# A candle was left burning inside a closed shop.
# Our apartment’s emergency exit is blocked, making fire escape difficult.
# A neighbor stores flammable items in their garage.
# A power strip in our office is overheating.
# A cigarette butt started a minor burn in the grass.
# A heater was left on unattended in a house.
# Someone was seen storing fireworks in a residential building.
# The fire alarm in our office is not working.
# A restaurant’s gas connection seems unsafe.
# A bonfire site was not properly extinguished.
# A small flare-up occurred in a mechanic's workshop but was controlled.
# A junkyard has a pile of flammable waste.
# The emergency fire exit in a cinema hall is locked.
# A bus driver is smoking near the fuel tank.
# A fire alarm in a school is malfunctioning frequently.
# An illegal fireworks sale is happening in a crowded market.
# A factory storing paint and chemicals has no fire safety equipment.
# A vendor is using an open flame near a petrol pump.
# A construction site has unattended welding sparks.
# A neighbor frequently burns incense sticks near curtains.
# A temporary roadside food stall has unsafe gas connections.
# A building under construction lacks fire safety exits.
# A truck carrying flammable liquids seems poorly maintained.
# Fire safety drills are not conducted in our office.
# A grocery store is selling expired and contaminated baby food.
# A local pharmacy is selling counterfeit medicines.
# A restaurant is serving food with visible mold and insects.
# A gas cylinder delivered by a vendor is leaking and could cause an explosion.
# A company is running a Ponzi scheme and scamming thousands of investors.
# A hospital is overcharging patients by adding fake medical tests.
# A retailer is illegally selling banned hazardous products to consumers.
# A car dealer sold a defective vehicle, which caused an accident.
# A seller is refusing to replace a faulty electrical appliance that caught fire.
# A fraudulent loan company is extorting customers with illegal interest rates.
# A telecom provider is charging hidden fees on monthly bills.
# An online shopping platform delivered a fake branded smartphone.
# A travel agency is refusing to refund canceled tickets despite their policy.
# A retailer is charging extra for digital payments.
# A cosmetics brand is falsely advertising their product as organic.
# A water purifier company is not providing promised free maintenance.
# A gym refused to cancel my membership and keeps deducting monthly fees.
# An airline lost my baggage and is not providing compensation.
# A bank is adding hidden charges to my savings account without notice.
# A hotel refused to honor my prepaid booking and charged extra for a room.
# A home appliance brand delivered a defective refrigerator and refused repair.
# A company’s customer service is refusing to take responsibility for a product defect.
# An online seller sent an empty package instead of my ordered item.
# A restaurant charged extra service fees without informing customers.
# A private school is charging extra fees without justification.
# An insurance company is refusing to process my valid claim.
# A ride-hailing service charged me for a trip I did not take.
# A local supermarket is mislabeling imported goods as locally made.
# A jewelry store sold fake gold and refused to take it back.
# A health supplement company is making false medical claims.
# A clothing store refused to accept a return even though the policy allows it.
# An e-commerce website delayed my order delivery by a week.
# A restaurant did not provide an item I paid for in my takeaway order.
# A mobile network provider has slow internet despite their 5G claim.
# A supermarket scanner charged a higher price than the displayed tag.
# A local bakery increased prices without updating the menu.
# A courier service delayed my parcel without any updates.
# A cafe refused to provide an itemized bill.
# A home service provider did not complete the work properly.
# A beauty salon overcharged me for a service compared to their price list.
# An electronic store charged extra for installation despite it being included.
# A cinema hall is charging extra for 3D glasses separately.
# A water bottle in a hotel costs 5 times the MRP.
# An online food delivery app canceled my order without reason.
# A clothing store is not displaying proper price tags.
# A local vendor is selling fruits at much higher prices than market rate.
# A fast-food chain denied me a discount that was advertised.
# A furniture store delivered a different color than what was ordered.
# A mall parking lot charged me double the normal rate.
# A coffee shop charged extra for takeaway packaging.
# A child has been abandoned near the railway station and is crying for help.
# A young girl is being physically abused by her guardians.
# A child is locked inside a house without food or water for several days.
# I witnessed a man forcefully taking a child inside a vehicle.
# A minor girl has been kidnapped from our neighborhood.
# A child is being forced to beg on the streets.
# A 10-year-old boy is being severely beaten by his employer at a shop.
# A toddler was left alone in a car for hours under extreme heat.
# A minor is being forced into child labor at a construction site.
# An underage girl is being married off against her will.
# A newborn was found abandoned near a garbage dump.
# Children in an orphanage are being physically tortured by the caretakers.
# A child is being trafficked for illegal activities.
# A disabled child is left unattended at a bus station.
# A child is locked inside a storehouse, crying for help.
# A minor boy was seen working in a hazardous chemical factory.
# A teenage girl is being harassed by an adult male repeatedly.
# Children in a local shelter home are being denied food and medical care.
# A baby was seen abandoned at a temple.
# A 12-year-old girl is being forced into domestic labor.
# A schoolteacher is verbally abusing students regularly.
# A child in our neighborhood is left alone at home daily while parents work.
# Children at a daycare are not being given proper meals.
# A shopkeeper is making minors work beyond permissible hours.
# A young boy has been skipping school and is seen working at a tea stall.
# A group of minors is being encouraged to sell goods on trains.
# A child is showing signs of neglect and malnourishment.
# A minor is being forced to work as a waiter in a restaurant.
# A girl has been missing from our colony for a few days.
# A child was found sleeping outside a shop at night.
# A group of children is living under a bridge without adult supervision.
# A neighbor frequently locks their child outside their house as punishment.
# Children in a foster home are complaining about being mistreated.
# A teacher publicly shames students, affecting their mental health.
# A child is constantly seen begging near a traffic signal.
# A minor boy is working as a cleaner in a bus depot.
# A child in my neighborhood appears to be physically weak due to poor nutrition.
# A foster family is not providing a safe environment for the children.
# A mother is threatening to abandon her child.
# An underage boy is being encouraged to drive a vehicle by his parents.
# A 14-year-old boy is being forced to work in a bakery instead of attending school.
# Children in a boarding school are living in unhygienic conditions.
# A teenager is frequently involved in theft and needs rehabilitation support.
# A mentally challenged child is not being taken care of by their guardians.
# A young girl is being discouraged from attending school.
# A minor is addicted to drugs due to peer pressure.
# A child is consistently missing school due to family negligence.
# A 7-year-old boy was found wandering alone in the market.
# A minor is facing online bullying and harassment.
# A family is not providing necessary medical care for their sick child.
# A foster home is overcrowded, and children are not receiving proper attention.
# A child is frequently seen inappropriately dressed and shivering in cold weather.
# Children in a local slum are not being sent to school.
# A teenage girl is under immense family pressure to quit her studies.
# A child with a disability is not receiving proper care at home.
# A minor is being encouraged to participate in gambling activities.
# A young child was left at a train station for hours without supervision.
# Children are being made to perform stunts on roads for money.
# Children in our locality are playing on the road unsupervised.
# A school does not have a proper playground for students.
# A child was seen eating food from a dustbin.
# A 16-year-old is being given alcohol by local shopkeepers.
# Children in an apartment are playing near an open drain.
# A boy is continuously seen roaming around the market during school hours.
# A child is found playing video games at an internet café all day.
# A child is frequently seen sleeping in a shop during the day.
# A group of kids is using abusive language and harassing passersby.
# A minor boy is riding a motorbike without a helmet.
# Teenagers are using an abandoned plot as a smoking spot.
# A child was seen playing near an open well.
# A neighbor regularly leaves their child with strangers.
# A school bus driver is allowing children to travel standing inside.
# A vendor is selling expired snacks to children.
# An 8-year-old was seen carrying heavy items in a market.
# A minor is found collecting money from people pretending to be sick.
# Children in a playground are left unattended till late at night.
# A school does not have proper drinking water facilities for students.
# Children are seen riding bicycles on busy roads without safety gear.
# A boy was caught shoplifting and needs guidance instead of punishment.
# A school has inadequate toilet facilities for girls.
# Teenagers are frequently found fighting in public parks.
# A child was seen attempting to cross a busy highway alone.
# A small child is being left alone with a pet dog all day.
# Children are seen bursting firecrackers in a dangerous manner.
# A boy is found frequently skipping school and loitering around.
# A minor is spending excessive time in a video gaming center.
# A local tuition center is overcrowded with students.
# A teenage girl is being pressurized to work instead of studying.
# A severe accident occurred at the main highway, multiple injuries reported.
# A drunk driver is speeding through residential areas.
# A traffic signal is not working at a major intersection, causing chaos.
# A truck overloaded with hazardous chemicals has overturned.
# A driver hit a pedestrian and fled the scene.
# A school bus is driving recklessly with children onboard.
# An ambulance is stuck in traffic due to illegal parking.
# A large pothole on a busy road is causing vehicles to lose control.
# A bridge has developed visible cracks, posing a danger to commuters.
# A speeding car is driving in the wrong direction on a one-way road.
# A driver is using a fake number plate.
# Illegal street racing is taking place in the city at night.
# A commercial vehicle is emitting excessive smoke, causing pollution.
# A traffic officer is asking for a bribe instead of issuing a ticket.
# Heavy vehicles are entering a no-entry zone for trucks.
# An intersection is heavily congested due to improper traffic management.
# Bikers are riding without helmets in a high-speed zone.
# Public buses are stopping in the middle of the road to pick up passengers.
# Vehicles are constantly jumping red lights at a particular junction.
# A ride-hailing cab is dangerously overtaking other vehicles.
# An auto-rickshaw driver is refusing to go by the meter and overcharging.
# Illegal vendors have occupied half the road, causing traffic blockage.
# A newly installed speed breaker is unmarked, causing sudden braking.
# A fuel tanker is leaking on the highway, causing a fire hazard.
# Motorcyclists are performing stunts in a public area.
# Cyclists are using expressways meant only for motor vehicles.
# There are no pedestrian crossings near a school, making it unsafe for children.
# A flyover is under construction, but proper safety measures are missing.
# Multiple auto-rickshaws are parked illegally, blocking a busy road.
# Traffic signs are missing from a newly developed road.
# A car is parked in a no-parking zone near a shopping mall.
# A minor fender-bender has caused a small traffic jam.
# A streetlight near a traffic intersection is not functioning.
# A driver is honking excessively despite no traffic jam.
# Multiple vehicles are parked haphazardly in a residential area.
# A zebra crossing has faded, making it difficult for pedestrians to see.
# A truck is blocking the sidewalk by parking on it.
# A road construction project is taking longer than expected.
# A newly installed traffic signal has unclear timings.
# A bus stop shelter is broken, leaving commuters exposed to the weather.
# Speed limit signs are too small and not visible at night.
# There is a minor oil spill on the side of the road.
# A footbridge is covered in advertisements, making signs hard to read.
# A new roundabout is confusing drivers unfamiliar with the area.
# A U-turn sign has been removed, causing confusion for commuters.
# A wrong-way driver caused a brief delay but was corrected quickly.
# A temporary traffic diversion is not properly marked.
# A parking lot exit is poorly designed, leading to unnecessary congestion.
# A pedestrian walkway is partially blocked by construction materials.
# There is no designated space for cycle riders on busy roads.
# A homeless shelter has run out of food and people are starving.
# An elderly home is severely understaffed, leading to neglect of residents.
# A mentally challenged individual is being physically abused by caretakers.
# A disabled person is being denied government benefits unlawfully.
# A child was abandoned near a railway station and needs immediate help.
# A domestic violence survivor is in urgent need of shelter.
# A community kitchen has shut down, leaving hundreds without food.
# A poor family has been evicted illegally and is living on the streets.
# A shelter for women is being forcibly shut down by local authorities.
# A group of elderly beggars is being harassed and driven away from public places.
# A widow is not receiving the pension she is entitled to.
# A disabled individual is facing discrimination at a government office.
# A senior citizen is being denied free medical assistance.
# A community welfare program has been discontinued without notice.
# A family living below the poverty line is not getting their ration.
# A government hospital is refusing to treat homeless individuals.
# A women’s self-help group is being denied financial aid.
# A laborer was denied wages under the government’s employment scheme.
# A local welfare office is delaying applications for disability benefits.
# A family affected by a natural disaster has not received promised relief.
# A government-run orphanage lacks basic facilities for children.
# A mentally ill person is wandering the streets without care.
# A rehabilitation center for drug abuse victims is not functional.
# An NGO providing aid to underprivileged children is facing legal hurdles.
# A shelter home has poor sanitation, causing health issues.
# A poor pregnant woman is unable to access free maternal care services.
# A job guarantee scheme is not properly implemented in the village.
# A remote tribal community is not receiving government aid.
# A government official is misusing welfare funds meant for the poor.
# A disabled student is being denied scholarships and benefits.
# A welfare office takes too long to process benefit applications.
# A helpline for social welfare services is always busy.
# A website for applying for social benefits is not working properly.
# A local community center has reduced its working hours.
# A small town lacks awareness programs on government welfare schemes.
# A welfare department is slow in responding to citizens’ queries.
# A newly launched free meal program has limited food options.
# A community library funded by welfare programs is not well-maintained.
# A training program for unemployed youth has been postponed.
# A free skill development course lacks proper instructors.
# A senior citizens’ recreational center has insufficient seating.
# A social worker assigned to a case is frequently unavailable.
# A government office does not provide proper facilities for disabled visitors.
# A free medical check-up camp was not well-organized.
# A housing project for the poor is facing minor delays.
# A shelter home lacks adequate recreational activities for children.
# A beneficiary is unable to track the status of their welfare application.
# A public grievance redressal system is slow to respond.
# A community garden for elderly citizens is not being maintained.
# A free government transport service for disabled people has irregular timings.
# A bridge has collapsed, and an alternative route is needed for relief workers.
# A cyclone has destroyed homes, and people have no shelter, food, or drinking water.
# There is a shortage of drinking water after the cyclone, but we still have some reserves.
# A bridge has collapsed, and an alternative route is needed for relief workers.
# The relief camp has run out of food supplies, and people are starving.
# A large fire has broken out in a residential area, and we need immediate evacuation assistance.
# A large fire has broken out in a residential area, and we need immediate evacuation assistance.
# A tree has fallen on the main road due to heavy rain, blocking traffic.
# A landslide has blocked all exit routes, and villagers are cut off from essential supplies.
# A strong storm has damaged houses, and people need temporary shelters.
# There is a shortage of drinking water after the cyclone, but we still have some reserves.
# A strong storm has damaged houses, and people need temporary shelters.
# A bridge has collapsed, and an alternative route is needed for relief workers.
# A large fire has broken out in a residential area, and we need immediate evacuation assistance.
# Power lines are down due to a storm, and we have had no electricity for three days.
# Heavy rains have flooded roads, making transportation impossible.
# A bridge has collapsed, and an alternative route is needed for relief workers.
# A large fire has broken out in a residential area, and we need immediate evacuation assistance.
# Power lines are down due to a storm, and we have had no electricity for three days.
# There is a minor waterlogging issue in our locality after the storm.
# A cyclone has destroyed homes, and people have no shelter, food, or drinking water.
# Heavy rains have flooded roads, making transportation impossible.
# A severe earthquake has collapsed buildings, and many people are trapped under the debris.
# A bridge has collapsed, and an alternative route is needed for relief workers.
# A cyclone has destroyed homes, and people have no shelter, food, or drinking water.
# There is a minor waterlogging issue in our locality after the storm.
# A tree has fallen on the main road due to heavy rain, blocking traffic.
# Power lines are down due to a storm, and we have had no electricity for three days.
# Power lines are down due to a storm, and we have had no electricity for three days.
# A bridge has collapsed, and an alternative route is needed for relief workers.
# The relief camp has run out of food supplies, and people are starving.
# A large fire has broken out in a residential area, and we need immediate evacuation assistance.
# There is a minor waterlogging issue in our locality after the storm.
# A strong storm has damaged houses, and people need temporary shelters.
# A tree has fallen on the main road due to heavy rain, blocking traffic.
# A massive flood has submerged our entire village, and people are stranded on rooftops.
# A landslide has blocked all exit routes, and villagers are cut off from essential supplies.
# A large fire has broken out in a residential area, and we need immediate evacuation assistance.
# Power lines are down due to a storm, and we have had no electricity for three days.
# A landslide has blocked all exit routes, and villagers are cut off from essential supplies.
# A severe earthquake has collapsed buildings, and many people are trapped under the debris.
# The relief camp has run out of food supplies, and people are starving.
# A strong storm has damaged houses, and people need temporary shelters.
# There is a minor waterlogging issue in our locality after the storm.
# A strong storm has damaged houses, and people need temporary shelters.
# A cyclone has destroyed homes, and people have no shelter, food, or drinking water.
# There is a minor waterlogging issue in our locality after the storm.
# There is a shortage of drinking water after the cyclone, but we still have some reserves.
# Some houses have suffered minor roof damage due to strong winds.
# A tree has fallen on the main road due to heavy rain, blocking traffic.
# A tree has fallen on the main road due to heavy rain, blocking traffic.
# Some houses have suffered minor roof damage due to strong winds.
# The local drainage system is clogged due to heavy rain, causing inconvenience.
# Some houses have suffered minor roof damage due to strong winds.
# A landslide has blocked all exit routes, and villagers are cut off from essential supplies.
# Some houses have suffered minor roof damage due to strong winds.
# Some houses have suffered minor roof damage due to strong winds.
# A tree has fallen on the main road due to heavy rain, blocking traffic.
# A massive flood has submerged our entire village, and people are stranded on rooftops.
# The relief camp has run out of food supplies, and people are starving.
# A large fire has broken out in a residential area, and we need immediate evacuation assistance.
# A large fire has broken out in a residential area, and we need immediate evacuation assistance.
# A landslide has blocked all exit routes, and villagers are cut off from essential supplies.
# A tree has fallen on the main road due to heavy rain, blocking traffic.
# The relief camp has run out of food supplies, and people are starving.
# The relief camp has run out of food supplies, and people are starving.
# A bridge has collapsed, and an alternative route is needed for relief workers.
# Some houses have suffered minor roof damage due to strong winds.
# The local drainage system is clogged due to heavy rain, causing inconvenience.
# A landslide has blocked all exit routes, and villagers are cut off from essential supplies.
# A large fire has broken out in a residential area, and we need immediate evacuation assistance.
# Heavy rains have flooded roads, making transportation impossible.
# Power lines are down due to a storm, and we have had no electricity for three days.
# A bridge has collapsed, and an alternative route is needed for relief workers.
# The local drainage system is clogged due to heavy rain, causing inconvenience.
# A landslide has blocked all exit routes, and villagers are cut off from essential supplies.
# A strong storm has damaged houses, and people need temporary shelters.
# Power lines are down due to a storm, and we have had no electricity for three days.
# The local drainage system is clogged due to heavy rain, causing inconvenience.
# A large fire has broken out in a residential area, and we need immediate evacuation assistance.
# Heavy rains have flooded roads, making transportation impossible.
# There is a shortage of drinking water after the cyclone, but we still have some reserves.
# The relief camp has run out of food supplies, and people are starving.
# A strong storm has damaged houses, and people need temporary shelters.
# The local drainage system is clogged due to heavy rain, causing inconvenience.
# A strong storm has damaged houses, and people need temporary shelters.
# A tree has fallen on the main road due to heavy rain, blocking traffic.
# A tree has fallen on the main road due to heavy rain, blocking traffic.
# A landslide has blocked all exit routes, and villagers are cut off from essential supplies.
# A tree has fallen on the main road due to heavy rain, blocking traffic.
# There is a shortage of drinking water after the cyclone, but we still have some reserves.
# A strong storm has damaged houses, and people need temporary shelters.
# A cyclone has destroyed homes, and people have no shelter, food, or drinking water.
# There is a shortage of drinking water after the cyclone, but we still have some reserves.
# A massive flood has submerged our entire village, and people are stranded on rooftops.
# A massive flood has submerged our entire village, and people are stranded on rooftops.
# A tree has fallen on the main road due to heavy rain, blocking traffic.
# Some houses have suffered minor roof damage due to strong winds.
# A landslide has blocked all exit routes, and villagers are cut off from essential supplies.
# There is a shortage of drinking water after the cyclone, but we still have some reserves.
# A government officer is demanding a bribe of ₹50,000 to process my land registration.
# Bribes are being collected for issuing driving licenses without tests.
# A police officer refused to file an FIR until I paid him ₹10,000.
# A clerk is demanding ₹500 to approve my birth certificate application.
# A railway employee is taking money to confirm waiting list tickets.
# A municipal worker demands a small fee to collect garbage regularly.
# Local politicians are involved in embezzling funds from the road construction project.
# Traffic police let people go without fines if they pay ₹200 as an 'adjustment'.
# The municipal officer is extorting money from shopkeepers for unauthorized stalls.
# Local politicians are involved in embezzling funds from the road construction project.
# Teachers in a government school are demanding extra money for free education benefits.
# The municipal officer is extorting money from shopkeepers for unauthorized stalls.
# A government officer is demanding a bribe of ₹50,000 to process my land registration.
# An official is delaying my pension clearance unless I pay ₹5,000.
# An official is delaying my pension clearance unless I pay ₹5,000.
# A clerk is demanding ₹500 to approve my birth certificate application.
# Local politicians are involved in embezzling funds from the road construction project.
# Teachers in a government school are demanding extra money for free education benefits.
# A hospital staff is demanding money to release my patient's medical reports.
# The municipal officer is extorting money from shopkeepers for unauthorized stalls.
# The electricity board is delaying meter installation until a bribe is paid.
# A clerk is demanding ₹500 to approve my birth certificate application.
# A police officer refused to file an FIR until I paid him ₹10,000.
# The electricity board is delaying meter installation until a bribe is paid.
# Local politicians are involved in embezzling funds from the road construction project.
# Traffic police let people go without fines if they pay ₹200 as an 'adjustment'.
# Traffic police let people go without fines if they pay ₹200 as an 'adjustment'.
# Traffic police let people go without fines if they pay ₹200 as an 'adjustment'.
# The electricity board is delaying meter installation until a bribe is paid.
# A police officer refused to file an FIR until I paid him ₹10,000.
# A bank officer is asking for a commission to approve my loan faster.
# Bribes are being collected for issuing driving licenses without tests.
# Teachers in a government school are demanding extra money for free education benefits.
# Local politicians are involved in embezzling funds from the road construction project.
# Traffic police let people go without fines if they pay ₹200 as an 'adjustment'.
# A government officer is demanding a bribe of ₹50,000 to process my land registration.
# A hospital staff is demanding money to release my patient's medical reports.
# A municipal worker demands a small fee to collect garbage regularly.
# An official is delaying my pension clearance unless I pay ₹5,000.
# Local politicians are involved in embezzling funds from the road construction project.
# An official is delaying my pension clearance unless I pay ₹5,000.
# A government officer is demanding a bribe of ₹50,000 to process my land registration.
# The municipal officer is extorting money from shopkeepers for unauthorized stalls.
# A government employee is misusing public funds meant for flood relief.
# The municipal officer is extorting money from shopkeepers for unauthorized stalls.
# An official is delaying my pension clearance unless I pay ₹5,000.
# A police officer refused to file an FIR until I paid him ₹10,000.
# A bank officer is asking for a commission to approve my loan faster.
# A government employee is misusing public funds meant for flood relief.
# Teachers in a government school are demanding extra money for free education benefits.
# A government officer is demanding a bribe of ₹50,000 to process my land registration.
# An official is delaying my pension clearance unless I pay ₹5,000.
# A bank officer is asking for a commission to approve my loan faster.
# Bribes are being collected for issuing driving licenses without tests.
# Traffic police let people go without fines if they pay ₹200 as an 'adjustment'.
# The electricity board is delaying meter installation until a bribe is paid.
# An official is delaying my pension clearance unless I pay ₹5,000.
# A clerk is demanding ₹500 to approve my birth certificate application.
# The municipal officer is extorting money from shopkeepers for unauthorized stalls.
# A hospital staff is demanding money to release my patient's medical reports.
# A clerk is demanding ₹500 to approve my birth certificate application.
# Local politicians are involved in embezzling funds from the road construction project.
# Teachers in a government school are demanding extra money for free education benefits.
# Teachers in a government school are demanding extra money for free education benefits.
# A municipal worker demands a small fee to collect garbage regularly.
# Bribes are being collected for issuing driving licenses without tests.
# A government employee is misusing public funds meant for flood relief.
# A government employee is misusing public funds meant for flood relief.
# The municipal officer is extorting money from shopkeepers for unauthorized stalls.
# A police officer refused to file an FIR until I paid him ₹10,000.
# The electricity board is delaying meter installation until a bribe is paid.
# A municipal worker demands a small fee to collect garbage regularly.
# Teachers in a government school are demanding extra money for free education benefits.
# A police officer refused to file an FIR until I paid him ₹10,000.
# Bribes are being collected for issuing driving licenses without tests.
# A railway employee is taking money to confirm waiting list tickets.
# Teachers in a government school are demanding extra money for free education benefits.
# Local politicians are involved in embezzling funds from the road construction project.
# A bank officer is asking for a commission to approve my loan faster.
# Traffic police let people go without fines if they pay ₹200 as an 'adjustment'.
# Local politicians are involved in embezzling funds from the road construction project.
# The electricity board is delaying meter installation until a bribe is paid.
# Traffic police let people go without fines if they pay ₹200 as an 'adjustment'.
# The municipal officer is extorting money from shopkeepers for unauthorized stalls.
# An official is delaying my pension clearance unless I pay ₹5,000.
# A railway employee is taking money to confirm waiting list tickets.
# A municipal worker demands a small fee to collect garbage regularly.
# A municipal worker demands a small fee to collect garbage regularly.
# An official is delaying my pension clearance unless I pay ₹5,000.
# Local politicians are involved in embezzling funds from the road construction project.
# Local politicians are involved in embezzling funds from the road construction project.
# A hospital staff is demanding money to release my patient's medical reports.
# Teachers in a government school are demanding extra money for free education benefits.
# A government officer is demanding a bribe of ₹50,000 to process my land registration.
# A government employee is misusing public funds meant for flood relief.
# Traffic police let people go without fines if they pay ₹200 as an 'adjustment'.
# Traffic police let people go without fines if they pay ₹200 as an 'adjustment'.
# A clerk is demanding ₹500 to approve my birth certificate application.
# Teachers in a government school are demanding extra money for free education benefits.
# A bank officer is asking for a commission to approve my loan faster.
# A prisoner is being tortured in custody, and their life is in danger.
# A journalist has been kidnapped after reporting on government corruption.
# Police brutality has resulted in severe injuries to peaceful protestors.
# A child labor camp has been discovered, where minors are being abused.
# A woman has been illegally detained and is being denied legal assistance.
# A community is being forcefully evicted without notice or rehabilitation.
# A whistleblower has received death threats for exposing illegal activities.
# A mentally ill person has been locked in a facility without proper care.
# A family is being persecuted due to their religious beliefs.
# A sexual assault survivor is being denied medical care and legal support.
# Prisoners are being denied proper food and medical care.
# A company is forcing workers to work under inhumane conditions.
# A transgender individual is being discriminated against in employment.
# A disabled person is being denied access to public facilities.
# A senior citizen has been abandoned by their family and needs assistance.
# A tribal community is being denied access to basic healthcare.
# A refugee family is being mistreated in a government shelter.
# A group of students has been suspended for raising concerns about discrimination.
# Authorities are ignoring complaints of bonded labor in a factory.
# A person is being refused their right to legal representation in court.
# A media house is being unfairly censored for reporting on social issues.
# An underprivileged child has been denied admission to a public school.
# Police are delaying registering an FIR for a caste-based violence case.
# A company is monitoring and restricting employees' right to privacy.
# A journalist has been unfairly arrested for exposing police misconduct.
# A woman is being denied maternity benefits at her workplace.
# A disabled student is not being provided proper education facilities.
# A community’s access to drinking water is being restricted by authorities.
# A village is being cut off from communication due to government negligence.
# A local shop is refusing to serve people from a particular community.
# A person is facing discrimination while renting a house.
# A hospital is charging extra fees from people of lower economic backgrounds.
# A private company is conducting mandatory unpaid overtime.
# A school is forcing students to follow a particular dress code.
# A public event is not wheelchair accessible.
# A workplace has no grievance redressal system for employee complaints.
# A local transport system is not allowing physically challenged individuals easy access.
# A library is refusing membership to economically weaker individuals.
# A person was asked unnecessary personal questions while applying for a job.
# A street performer was harassed by authorities for no valid reason.
# A social media post on human rights issues was unfairly taken down.
# An organization is discriminating against employees based on their political beliefs.
# A hotel denied entry to an individual based on their appearance.
# A government office does not provide information in regional languages.
# A protest was disrupted even though it had prior approval.
# A group was not allowed to form a legal workers' union.
# A senior citizen was denied a pension due to bureaucratic delays.
# A historical site does not provide access to differently-abled visitors.
# A shop is charging higher prices to migrant workers.
# A major sewage pipeline has burst, causing flooding in residential areas.
# A building under construction has collapsed, trapping people inside.
# A garbage dump has caught fire, causing toxic fumes.
# A water supply pipeline has burst, leaving thousands without drinking water.
# A main road has caved in due to heavy rains, creating a dangerous sinkhole.
# A dead body has been lying unattended on a public road for hours.
# A street is completely submerged due to clogged drainage, blocking emergency vehicles.
# An open electric pole wire is sparking and posing an electrocution risk.
# A tree has fallen on a busy road, blocking traffic completely.
# A manhole is open on a highway, leading to accidents.
# Streetlights in a neighborhood have been non-functional for weeks.
# Garbage collection in a locality has been irregular for a month.
# A playground meant for children has turned into a dumping ground.
# Illegal encroachments on footpaths are making it difficult for pedestrians.
# Public toilets are in extremely unhygienic conditions and need maintenance.
# A local park is being used for illegal activities at night.
# Stray dogs have increased in the area, posing a threat to residents.
# Water supplied in the colony has a foul smell and may be contaminated.
# A recently constructed road has developed deep cracks.
# Construction debris is being dumped illegally in open areas.
# A community water tank is leaking and causing water wastage.
# Public transport buses are not stopping at designated bus stops.
# A market area lacks proper waste disposal bins.
# An illegal slaughterhouse is operating in a residential area.
# Several potholes on a bridge make it unsafe for vehicles.
# A neighborhood lacks a proper drainage system, causing frequent waterlogging.
# A government school building is in poor condition and unsafe for children.
# A newly built community hall remains closed without any notice.
# A hospital waste dump is emitting a strong, foul odor.
# A street vendor market is blocking emergency exits of nearby buildings.
# An open gym in the park has some broken equipment.
# Street name boards are faded and unreadable.
# A bus stop shelter has a broken roof.
# Traffic signal buttons for pedestrians are not working properly.
# A recently painted wall has been defaced with posters.
# Civic workers are sweeping the streets only once instead of twice a day.
# A public water tap is leaking, wasting water.
# The community library has irregular working hours.
# An old water fountain in a park is not working.
# A new parking area lacks proper signboards.
# Benches in a public park are broken and need repair.
# Mosquito fogging is not being done regularly.
# There are no speed breakers near a school zone.
# Several dustbins are missing from a public garden.
# A heritage building is not being maintained properly.
# A new public bicycle-sharing system is not functional.
# Drainage cover slabs are missing in some areas, causing minor inconvenience.
# A new clock tower in the city is not working.
# An old public notice board is filled with outdated information.
# A community hall lacks proper ventilation and fans.
# A bridge in the city has developed large cracks, posing a collapse risk.
# A major water pipeline has burst, causing flooding in homes.
# A broken electric transformer is sparking continuously.
# Uncollected garbage is causing an outbreak of diseases in a slum area.
# A drainage system failure has led to severe flooding in the hospital area.
# Raw sewage is flowing into drinking water pipelines.
# A sudden gas leak has been detected near a residential area.
# An open borewell poses a danger to children in the area.
# An illegal industrial waste dump is emitting toxic fumes.
# A part of a flyover has collapsed, blocking a busy road.
# The local water supply is inconsistent and unreliable.
# A government-funded school lacks proper sanitation facilities.
# An open sewer is causing a bad smell and health issues.
# A major road in the city has deep potholes leading to frequent accidents.
# Illegal posters and banners are blocking traffic signs.
# A newly constructed road has already developed cracks.
# Street vendors have occupied public parking spaces.
# A community center is being misused for private events.
# A residential area has been without garbage collection for weeks.
# Encroachments on a public park have reduced green spaces.
# Several trees were cut down illegally, affecting the environment.
# Public transport buses are often overcrowded due to poor scheduling.
# Street sweepers have not been maintaining the market area.
# A road repair project has been abandoned halfway.
# Illegal dumping of construction materials is blocking footpaths.
# A faulty drainage system is causing foul smells near a school.
# Drinking water tanks in public spaces are not cleaned regularly.
# Illegal advertising banners are obstructing footpaths.
# An animal shelter run by the corporation lacks proper funding.
# The community park is being used for unauthorized commercial activities.
# A public dustbin has been damaged and is not being replaced.
# Waterlogging in parks is making them inaccessible after rain.
# Public benches in the town square need repainting.
# A local lake is not being cleaned regularly.
# A public notice board is filled with outdated information.
# A drinking water facility in a park has low water pressure.
# A community playground lacks swings and seesaws for children.
# Bus shelters are not cleaned regularly, making them unhygienic.
# City signboards have faded text, making navigation difficult.
# Public restrooms lack sufficient soap and toilet paper.
# The city’s public fountains are not operational.
# An open-air gym has broken workout equipment.
# A pedestrian bridge has dirty and slippery steps.
# Streetlights flicker on and off at night, causing inconvenience.
# City parks need more benches for elderly citizens.
# A neighborhood lacks a designated parking space for bicycles.
# Public gardens need better maintenance and replanting of flowers.
# A new road sign has been placed incorrectly, confusing drivers.
# A dog park is not properly fenced, allowing dogs to wander off.
# A city clock tower is not functioning properly.

# %%
data["Department"].unique()
# Out:
# array(['Police Department', 'Cyber Crime Department', 'Women Helpline',
#        'Fire Department', 'Consumer Protection Department',
#        'Child Welfare Department', 'Traffic Police Department',
#        'Social Welfare Department', 'Disaster Management',
#        'Anti-Corruption Bureau', 'Human Right Department',
#        'Muncipal Coporation Department'], dtype=object)

# %%
data["Complaint"]=data["Complaint"].apply(lambda x: x.lower())

# %%
stoplist=stopwords.words('english')

# %%
l=[]
for i in data["Complaint"]:
    temp=i.split()
    j=0
    while j<len(temp):
        if temp[j] in stoplist:
            temp.pop(j)
        else:
            j+=1
    l.append(" ".join(temp))

# %%
for i in range(len(l)):
    l[i]=l[i].replace(".","").replace("!","").replace("(","").replace(")","").replace(",","").replace("?","")
l
# Out:
# ['ongoing robbery house please send help immediately',
#  'witnessed kidnapping near central park',
#  'serious accident happened people injured',
#  'gang fight happening near street weapons',
#  'house fire need emergency services now',
#  'active shooter situation mall please respond urgently',
#  'child missing last seen near school playground',
#  'elderly person collapsed road unresponsive',
#  'man harassing threatening people knife subway',
#  'woman screaming help neighborhood fear domestic violence',
#  'suspicious vehicle parked outside house hours',
#  'neighbor keeps playing loud music late night disturbing everyone',
#  'lost phone metro station tracked',
#  'suspect someone dealing drugs near community park',
#  'abandoned bag train station looks suspicious',
#  'receiving scam calls claiming police department',
#  'street light broken weeks making unsafe night',
#  'found wallet street want return owner',
#  'someone scratched car parking lot left without informing',
#  'stray dog acting aggressively neighborhood might bite someone',
#  'someone blocking driveway vehicle',
#  'shopkeeper overcharging customers refusing give receipts',
#  'people spitting public places despite ban',
#  'potholes main road causing minor accidents',
#  'street vendor operating without license front shop',
#  'someone keeps throwing garbage front house every night',
#  'local park maintained properly full litter',
#  'kids bursting crackers odd hours disturbing residents',
#  'people feeding pigeons balcony creating mess',
#  'bikers performing stunts road causing inconvenience',
#  'car parked no-parking zone blocking entrance building',
#  'water leakage main road causing traffic congestion',
#  'street performer creating nuisance loudspeakers near market',
#  'person selling cigarettes minors outside school gate',
#  'miscreants damaging public property subway station',
#  'someone vandalized shop spray painting walls',
#  'cyclist hit speeding car driver fled scene',
#  'group teenagers drinking alcohol public park',
#  'snake backyard need animal control support',
#  'lost passport traveling need help report it',
#  'streetlight flickering making unsafe pedestrians night',
#  'landlord harassing refusing return deposit',
#  'received fake currency note shop need report it',
#  'delivery agent misbehaved refused deliver package',
#  'major traffic jam due overturned truck highway',
#  'strangers constantly loitering near house seems suspicious',
#  'colleague threatening work fear safety',
#  'atm area broken into suspect theft',
#  'group people gambling open area near house',
#  'people illegally cutting trees community park',
#  'saw someone trying break parked car last night',
#  'dead animal road causing foul smell hygiene issues',
#  'wedding procession blocking road causing heavy traffic',
#  'bike stolen parking lot need report it',
#  'credit card details stolen unauthorized transactions made',
#  'group people blocking road protest without permission',
#  'friend gone missing last seen near railway station',
#  'unknown number calling threatening repeatedly',
#  'chemical spill near factory causing hazardous situation',
#  'reckless driver almost hit pedestrians near school zone',
#  'domestic helper suddenly disappeared cannot contact them',
#  'people selling illegal firecrackers outside temple area',
#  'man attempting break locked car parking lot',
#  'illegal hoardings blocking visibility intersections',
#  'beggar harassing commuters bus stop money',
#  'suspect tenant running illegal business house',
#  'power outage street thieves might take advantage',
#  'vehicle tinted windows moving suspiciously around area',
#  'children climbing under-construction building it’s unsafe',
#  'local vendor dumping garbage nearby lake',
#  'neighbor’s pet keeps trespassing property causing damage',
#  'firecracker store caught fire spreading smoke area',
#  'saw someone pickpocketing crowded train station',
#  'man behaving indecently towards women metro',
#  'individuals selling expired food products supermarket',
#  'man following continuously feel unsafe',
#  'package stolen doorstep away',
#  'large pothole highway causing accidents',
#  'someone ringing doorbell odd hours running away',
#  'drainage system overflowing flooding streets',
#  'house keys stolen along bag need assistance',
#  'illegal sand mining happening near riverbed night',
#  'truck over-speeding residential area risking lives',
#  'person smoking inside hospital despite warnings',
#  'neighbor burning trash causing smoke pollution',
#  'bus drivers refusing stop designated stops',
#  'found counterfeit notes cash given shop',
#  'security guard shopping mall misbehaved customers',
#  'group men trespassing private property near house',
#  'tourist got lost jungle trek returned',
#  'reports illegal arms trading near border',
#  'relative taken hospital hit-and-run case',
#  'domestic servant physically abused employer',
#  'someone left unidentified package apartment lobby',
#  'drone flying house repeatedly seems suspicious',
#  'someone hacked bank account transferred money',
#  'receiving death threats unknown person via email',
#  'social media account hacked hacker posting illegal content',
#  'cybercriminal blackmailing private photos',
#  'major data breach company sensitive data leaked',
#  'received email ransomware files locked',
#  "child's online gaming account compromised hacker demanding money",
#  'tricked installing malware device locked',
#  'hacker gained access cloud storage deleted files',
#  'someone created fake profile using identity scamming people',
#  'received email threatening expose personal data unless pay ransom',
#  "company's confidential data leaked dark web",
#  'hackers taken control business website demanding money',
#  'accidentally clicked fake paypal link account compromised',
#  'hacker using email send phishing links contacts',
#  'someone gained unauthorized access medical records',
#  'hackers accessed webcam recording without knowledge',
#  'received extortion email claiming access browsing history',
#  'cryptocurrency wallet hacked funds stolen',
#  'fraudulent loan taken name using stolen credentials',
#  'received phishing email pretending bank',
#  'fake e-commerce website scammed never delivered order',
#  'someone impersonating social media messaging friends',
#  'accidentally downloaded suspicious file computer slow',
#  'fraudulent investment scheme advertised online',
#  'credit card details stolen unauthorized transactions made',
#  'keep receiving scam calls asking otp',
#  'hacker tried access email able reset password',
#  'stranger keeps sending inappropriate messages social media',
#  'someone using wifi network without permission',
#  'social media influencer promoting fraudulent crypto investment scheme',
#  'scammer tricked sharing banking details call',
#  'lost money online job scam asked advance fee',
#  'someone created deepfake video shared online',
#  'keep getting fake invoices unknown companies via email',
#  'online gaming account hacked in-game purchases gone',
#  'fraudster running fake giveaway collect personal details',
#  'unknown device logged email without knowledge',
#  'scammer created fake online dating profile tricked sending money',
#  'software installed collecting personal data without consent',
#  'someone stole domain name using fraudulent activities',
#  'customer left false online review business damage reputation',
#  'bot continuously spamming blog fake comments',
#  'someone running lottery scam using name photos',
#  'found website selling personal information',
#  'keep getting random video calls strangers messaging apps',
#  'fake charity website scamming people name donations',
#  'hacker accessing work emails without authorization',
#  'increase fake tech support calls area',
#  'received email pretending police department asking money',
#  'fraudulent online training program collecting personal information',
#  'noticed someone trying access netflix streaming accounts',
#  'fake travel agency scammed non-existent vacation packages',
#  'bot network launching ddos attacks business website',
#  'influencer running scam contest real prizes',
#  'fake job recruiter asked pay training materials',
#  'scammer tried register phone number different telecom provider',
#  'keep getting spam emails despite blocking sender',
#  'old social media account hacked longer use it',
#  'got pop-up saying lottery click it',
#  'ad blocker isn’t working properly browser',
#  'online review company deleted without reason',
#  'suspect someone using ai generate fake images me',
#  'received promotional email unknown sender',
#  'app downloaded asking unnecessary permissions',
#  'someone created meme using photo without consent',
#  'keep getting fake friend requests unknown people',
#  'someone used email sign multiple random websites',
#  'keep seeing fake product reviews online shopping sites',
#  'website keeps auto-subscribing newsletter',
#  'someone using profile picture without permission',
#  'receiving many pop-up ads mobile browser',
#  'website asked disable antivirus downloading software',
#  'chatbot website giving misleading information',
#  'social media platform allowing delete old posts',
#  'gaming forum banned without valid reason',
#  'noticed social media feed showing many ads',
#  'email provider marking legitimate emails spam',
#  'received fake job offer linkedin',
#  'app installed draining phone battery abnormally fast',
#  'saw website selling fake brand-name clothing items',
#  'someone copying tweets reposting own',
#  'online banking app logs frequently without reason',
#  'saw scammer advertising fake digital marketing services',
#  'mobile banking app showing incorrect transaction history',
#  'weather app installed tracking location unnecessarily',
#  'website visited recently sending excessive notifications',
#  'facing domestic violence life danger',
#  'sexually harassed traveling alone night',
#  'man stalking every day near house',
#  'received rape threats social media',
#  'physically assaulted in-laws dowry demands',
#  'husband threatening kill report domestic abuse',
#  'drugged harassed party',
#  'stranger following trying force car',
#  'gang men harassing girls near college campus',
#  'forcibly taken unknown location held will',
#  'minor parents trying force marriage',
#  'partner locked inside house refusing let leave',
#  'saw girl forcefully dragged car group men',
#  'groped crowded public place one helped',
#  'someone blackmailing private pictures',
#  'local goon harassing girls threatening acid attacks',
#  'employer demanding sexual favors return salary',
#  'group men harassing female colleagues daily',
#  'found hidden camera hotel room',
#  'stranger forcibly entered house tried assault me',
#  'husband refuses give financial support children',
#  'landlord making inappropriate advances toward me',
#  'in-laws mentally torturing gave birth girl',
#  'ex-boyfriend sharing false rumors online',
#  'denied job woman',
#  'shopkeeper harassed went shopping alone',
#  'man keeps sending inappropriate messages despite blocking him',
#  'colleague keeps invading personal space work',
#  'facing constant pressure family quit job',
#  'brother controls financial transactions won’t let independent',
#  'man sending continuous messages despite warnings',
#  'husband secretly recording phone conversations',
#  'co-worker keeps making sexist jokes comments',
#  'man tried take pictures without consent public',
#  'stranger making obscene gestures every morning',
#  'group boys neighborhood teases girls pass by',
#  'friend abandoned husband refuses take responsibility',
#  'social media account posting edited pictures me',
#  'man threatened throw acid rejected proposal',
#  'boss keeps making inappropriate remarks appearance',
#  'husband’s family trying take away children me',
#  'forced quit studies girl',
#  'boy keeps spreading rumors college',
#  'workplace complaint mechanism sexual harassment',
#  'housemaid physically abused employer',
#  'body-shamed relatives causing mental distress',
#  'professor offering good grades exchange favors',
#  'fake marriage proposal used scam take money',
#  'daughter’s teacher behaving inappropriately her',
#  'touched inappropriately stranger public transport',
#  'colleague keeps forcing go despite refusals',
#  'landlord refuses rent apartment single woman',
#  'man stalking different social media platforms',
#  'family forcefully keeping daughter-in-law locked home',
#  'fiancé broke engagement refusing return belongings',
#  'friend emotionally blackmailed staying toxic relationship',
#  'constantly harassed boys coaching institute',
#  'husband took huge loan name without consent',
#  'man keeps staring public places making uncomfortable',
#  'keep receiving fake marriage proposals unknown people',
#  'husband doesn’t help household chores despite us working',
#  'co-worker makes fun working mothers office',
#  'parents don’t allow male friends',
#  'neighborhood boy keeps whistling girls pass by',
#  'feel unsafe walking alone night due lack streetlights',
#  'faced gender discrimination restaurant dining alone',
#  'boss refused approve maternity leave',
#  "allowed go alone due family's conservative mindset",
#  'family prefers brother educational opportunities',
#  'man keeps catcalling every time walk past shop',
#  'friends often dismiss safety concerns overreacting',
#  'street vendor tried flirt shopping',
#  'school proper sanitary facilities girls',
#  'distant relative keeps making uncomfortable comments appearance',
#  'group boys keeps following friends school',
#  'apartment complex allow single women rent apartments',
#  "cousin's husband often comments women stay home",
#  'boy class keeps asking personal questions despite refusals',
#  'neighborhood feel safe due lack police patrols',
#  'female colleague denied promotion despite qualified',
#  'forced wear traditional clothes family gathering',
#  'male relatives control family decisions ignoring female opinions',
#  "male passenger refused let sit reserved women's seat bus",
#  'parents refused let take job societal pressure',
#  'customer workplace keeps making sexist comments',
#  'group men often block way near college harass girls',
#  'boy tuition center keeps calling names',
#  'friend asked inappropriate questions job interview',
#  'major fire broken apartment complex people trapped inside',
#  'factory near house caught fire explosions occurring',
#  'gas cylinder exploded neighborhood fire spreading fast',
#  'car caught fire busy market area people panicking',
#  'fire broke school building students still inside',
#  'high-rise building fire people stranded top floors',
#  'huge fire hospital patients need immediate evacuation',
#  'petrol pump caught fire spreading rapidly',
#  'electric short circuit caused fire office building',
#  'slum area caught fire many families risk',
#  'bus full passengers caught fire highway',
#  'chemical factory explosion triggered large-scale fire',
#  'forest fire approaching residential areas',
#  'train compartment caught fire traveling',
#  'warehouse storing flammable materials burning',
#  'fire lpg storage facility',
#  'house colony caught fire due gas leak',
#  'oil tanker overturned caught fire main road',
#  'industrial unit dealing hazardous chemicals burning',
#  'restaurant kitchen fire gone control',
#  'burning smell smoke coming electrical transformer',
#  'shop market caught fire one trapped inside',
#  'fire broke garbage dump smoke unbearable',
#  'tree caught fire due short circuit electrical wires',
#  'minor fire broke atm cabin',
#  'truck carrying chemicals emitting smoke',
#  'small fire started parked vehicle',
#  'fire godown partially controlled',
#  'small explosion factory caused fire hazard',
#  'air conditioning unit office started emitting smoke',
#  'mobile tower caught fire thunderstorm',
#  'sparks welding work ignited minor fire construction site',
#  'power line fell started small fire residential area',
#  'bonfire public event got control',
#  'bakery caught fire due overheated oven',
#  'fire started temple due unattended oil lamps',
#  'unattended stove led minor kitchen fire',
#  'firecrackers ignited small fire empty lot',
#  'generator caught fire due overheating',
#  'tent wedding function caught fire',
#  'temporary festival stall caught fire nearby lamp',
#  "bank's ups room emitting excessive heat smoke",
#  'elevator machine room caught fire due overheating',
#  'small explosion petrol station caused minor fire',
#  'battery storage facility started emitting smoke',
#  'firework manufacturing unit minor fire incident',
#  'drone battery exploded started small fire',
#  "restaurant's chimney caught fire due excessive grease buildup",
#  'fire noticed inside mall’s food court kitchen',
#  'laundromat dryer overheated caught fire',
#  'home inverter battery exploded causing small fire',
#  'illegal lpg refill center caught fire',
#  'hotel room caught fire due unattended iron',
#  'cotton warehouse caught fire spark',
#  'cinema hall projection room fire incident',
#  'scrap yard fire creating dense smoke',
#  'fire car repair workshop spread nearby vehicles',
#  'wooden furniture shop caught fire welding spark',
#  'people burning dry leaves neighborhood creating smoke',
#  'someone lighting fireworks restricted area',
#  'local factory emitting smoke seems suspicious',
#  'someone burning trash open field',
#  'street vendor using illegal gas cylinder',
#  'fire extinguisher office empty',
#  'chimney bakery emitting excessive smoke',
#  'transformer street making crackling noise',
#  'barbecue park left unattended',
#  'sparks noticed coming street lamp post',
#  'garbage pile near house smoldering',
#  'festival decoration caught fire immediately put out',
#  'car’s exhaust pipe emitted flames momentarily',
#  'someone using high-voltage electrical appliances without safety precautions',
#  'candle left burning inside closed shop',
#  'apartment’s emergency exit blocked making fire escape difficult',
#  'neighbor stores flammable items garage',
#  'power strip office overheating',
#  'cigarette butt started minor burn grass',
#  'heater left unattended house',
#  'someone seen storing fireworks residential building',
#  'fire alarm office working',
#  'restaurant’s gas connection seems unsafe',
#  'bonfire site properly extinguished',
#  "small flare-up occurred mechanic's workshop controlled",
#  'junkyard pile flammable waste',
#  'emergency fire exit cinema hall locked',
#  'bus driver smoking near fuel tank',
#  'fire alarm school malfunctioning frequently',
#  'illegal fireworks sale happening crowded market',
#  'factory storing paint chemicals fire safety equipment',
#  'vendor using open flame near petrol pump',
#  'construction site unattended welding sparks',
#  'neighbor frequently burns incense sticks near curtains',
#  'temporary roadside food stall unsafe gas connections',
#  'building construction lacks fire safety exits',
#  'truck carrying flammable liquids seems poorly maintained',
#  'fire safety drills conducted office',
#  'grocery store selling expired contaminated baby food',
#  'local pharmacy selling counterfeit medicines',
#  'restaurant serving food visible mold insects',
#  'gas cylinder delivered vendor leaking could cause explosion',
#  'company running ponzi scheme scamming thousands investors',
#  'hospital overcharging patients adding fake medical tests',
#  'retailer illegally selling banned hazardous products consumers',
#  'car dealer sold defective vehicle caused accident',
#  'seller refusing replace faulty electrical appliance caught fire',
#  'fraudulent loan company extorting customers illegal interest rates',
#  'telecom provider charging hidden fees monthly bills',
#  'online shopping platform delivered fake branded smartphone',
#  'travel agency refusing refund canceled tickets despite policy',
#  'retailer charging extra digital payments',
#  'cosmetics brand falsely advertising product organic',
#  'water purifier company providing promised free maintenance',
#  'gym refused cancel membership keeps deducting monthly fees',
#  'airline lost baggage providing compensation',
#  'bank adding hidden charges savings account without notice',
#  'hotel refused honor prepaid booking charged extra room',
#  'home appliance brand delivered defective refrigerator refused repair',
#  'company’s customer service refusing take responsibility product defect',
#  'online seller sent empty package instead ordered item',
#  'restaurant charged extra service fees without informing customers',
#  'private school charging extra fees without justification',
#  'insurance company refusing process valid claim',
#  'ride-hailing service charged trip take',
#  'local supermarket mislabeling imported goods locally made',
#  'jewelry store sold fake gold refused take back',
#  'health supplement company making false medical claims',
#  'clothing store refused accept return even though policy allows it',
#  'e-commerce website delayed order delivery week',
#  'restaurant provide item paid takeaway order',
#  'mobile network provider slow internet despite 5g claim',
#  'supermarket scanner charged higher price displayed tag',
#  'local bakery increased prices without updating menu',
#  'courier service delayed parcel without updates',
#  'cafe refused provide itemized bill',
#  'home service provider complete work properly',
#  'beauty salon overcharged service compared price list',
#  'electronic store charged extra installation despite included',
#  'cinema hall charging extra 3d glasses separately',
#  'water bottle hotel costs 5 times mrp',
#  'online food delivery app canceled order without reason',
#  'clothing store displaying proper price tags',
#  'local vendor selling fruits much higher prices market rate',
#  'fast-food chain denied discount advertised',
#  'furniture store delivered different color ordered',
#  'mall parking lot charged double normal rate',
#  'coffee shop charged extra takeaway packaging',
#  'child abandoned near railway station crying help',
#  'young girl physically abused guardians',
#  'child locked inside house without food water several days',
#  'witnessed man forcefully taking child inside vehicle',
#  'minor girl kidnapped neighborhood',
#  'child forced beg streets',
#  '10-year-old boy severely beaten employer shop',
#  'toddler left alone car hours extreme heat',
#  'minor forced child labor construction site',
#  'underage girl married will',
#  'newborn found abandoned near garbage dump',
#  'children orphanage physically tortured caretakers',
#  'child trafficked illegal activities',
#  'disabled child left unattended bus station',
#  'child locked inside storehouse crying help',
#  'minor boy seen working hazardous chemical factory',
#  'teenage girl harassed adult male repeatedly',
#  'children local shelter home denied food medical care',
#  'baby seen abandoned temple',
#  '12-year-old girl forced domestic labor',
#  'schoolteacher verbally abusing students regularly',
#  'child neighborhood left alone home daily parents work',
#  'children daycare given proper meals',
#  'shopkeeper making minors work beyond permissible hours',
#  'young boy skipping school seen working tea stall',
#  'group minors encouraged sell goods trains',
#  'child showing signs neglect malnourishment',
#  'minor forced work waiter restaurant',
#  'girl missing colony days',
#  'child found sleeping outside shop night',
#  'group children living bridge without adult supervision',
#  'neighbor frequently locks child outside house punishment',
#  'children foster home complaining mistreated',
#  'teacher publicly shames students affecting mental health',
#  'child constantly seen begging near traffic signal',
#  'minor boy working cleaner bus depot',
#  'child neighborhood appears physically weak due poor nutrition',
#  'foster family providing safe environment children',
#  'mother threatening abandon child',
#  'underage boy encouraged drive vehicle parents',
#  '14-year-old boy forced work bakery instead attending school',
#  'children boarding school living unhygienic conditions',
#  'teenager frequently involved theft needs rehabilitation support',
#  'mentally challenged child taken care guardians',
#  'young girl discouraged attending school',
#  'minor addicted drugs due peer pressure',
#  'child consistently missing school due family negligence',
#  '7-year-old boy found wandering alone market',
#  'minor facing online bullying harassment',
#  'family providing necessary medical care sick child',
#  'foster home overcrowded children receiving proper attention',
#  'child frequently seen inappropriately dressed shivering cold weather',
#  'children local slum sent school',
#  'teenage girl immense family pressure quit studies',
#  'child disability receiving proper care home',
#  'minor encouraged participate gambling activities',
#  'young child left train station hours without supervision',
#  'children made perform stunts roads money',
#  'children locality playing road unsupervised',
#  'school proper playground students',
#  'child seen eating food dustbin',
#  '16-year-old given alcohol local shopkeepers',
#  'children apartment playing near open drain',
#  'boy continuously seen roaming around market school hours',
#  'child found playing video games internet café day',
#  'child frequently seen sleeping shop day',
#  'group kids using abusive language harassing passersby',
#  'minor boy riding motorbike without helmet',
#  'teenagers using abandoned plot smoking spot',
#  'child seen playing near open well',
#  'neighbor regularly leaves child strangers',
#  'school bus driver allowing children travel standing inside',
#  'vendor selling expired snacks children',
#  '8-year-old seen carrying heavy items market',
#  'minor found collecting money people pretending sick',
#  'children playground left unattended till late night',
#  'school proper drinking water facilities students',
#  'children seen riding bicycles busy roads without safety gear',
#  'boy caught shoplifting needs guidance instead punishment',
#  'school inadequate toilet facilities girls',
#  'teenagers frequently found fighting public parks',
#  'child seen attempting cross busy highway alone',
#  'small child left alone pet dog day',
#  'children seen bursting firecrackers dangerous manner',
#  'boy found frequently skipping school loitering around',
#  'minor spending excessive time video gaming center',
#  'local tuition center overcrowded students',
#  'teenage girl pressurized work instead studying',
#  'severe accident occurred main highway multiple injuries reported',
#  'drunk driver speeding residential areas',
#  'traffic signal working major intersection causing chaos',
#  'truck overloaded hazardous chemicals overturned',
#  'driver hit pedestrian fled scene',
#  'school bus driving recklessly children onboard',
#  'ambulance stuck traffic due illegal parking',
#  'large pothole busy road causing vehicles lose control',
#  'bridge developed visible cracks posing danger commuters',
#  'speeding car driving wrong direction one-way road',
#  'driver using fake number plate',
#  'illegal street racing taking place city night',
#  'commercial vehicle emitting excessive smoke causing pollution',
#  'traffic officer asking bribe instead issuing ticket',
#  'heavy vehicles entering no-entry zone trucks',
#  'intersection heavily congested due improper traffic management',
#  'bikers riding without helmets high-speed zone',
#  'public buses stopping middle road pick passengers',
#  'vehicles constantly jumping red lights particular junction',
#  'ride-hailing cab dangerously overtaking vehicles',
#  'auto-rickshaw driver refusing go meter overcharging',
#  'illegal vendors occupied half road causing traffic blockage',
#  'newly installed speed breaker unmarked causing sudden braking',
#  'fuel tanker leaking highway causing fire hazard',
#  'motorcyclists performing stunts public area',
#  'cyclists using expressways meant motor vehicles',
#  'pedestrian crossings near school making unsafe children',
#  'flyover construction proper safety measures missing',
#  'multiple auto-rickshaws parked illegally blocking busy road',
#  'traffic signs missing newly developed road',
#  'car parked no-parking zone near shopping mall',
#  'minor fender-bender caused small traffic jam',
#  'streetlight near traffic intersection functioning',
#  'driver honking excessively despite traffic jam',
#  'multiple vehicles parked haphazardly residential area',
#  'zebra crossing faded making difficult pedestrians see',
#  'truck blocking sidewalk parking it',
#  'road construction project taking longer expected',
#  'newly installed traffic signal unclear timings',
#  'bus stop shelter broken leaving commuters exposed weather',
#  'speed limit signs small visible night',
#  'minor oil spill side road',
#  'footbridge covered advertisements making signs hard read',
#  'new roundabout confusing drivers unfamiliar area',
#  'u-turn sign removed causing confusion commuters',
#  'wrong-way driver caused brief delay corrected quickly',
#  'temporary traffic diversion properly marked',
#  'parking lot exit poorly designed leading unnecessary congestion',
#  'pedestrian walkway partially blocked construction materials',
#  'designated space cycle riders busy roads',
#  'homeless shelter run food people starving',
#  'elderly home severely understaffed leading neglect residents',
#  'mentally challenged individual physically abused caretakers',
#  'disabled person denied government benefits unlawfully',
#  'child abandoned near railway station needs immediate help',
#  'domestic violence survivor urgent need shelter',
#  'community kitchen shut down leaving hundreds without food',
#  'poor family evicted illegally living streets',
#  'shelter women forcibly shut local authorities',
#  'group elderly beggars harassed driven away public places',
#  'widow receiving pension entitled to',
#  'disabled individual facing discrimination government office',
#  'senior citizen denied free medical assistance',
#  'community welfare program discontinued without notice',
#  'family living poverty line getting ration',
#  'government hospital refusing treat homeless individuals',
#  'women’s self-help group denied financial aid',
#  'laborer denied wages government’s employment scheme',
#  'local welfare office delaying applications disability benefits',
#  'family affected natural disaster received promised relief',
#  'government-run orphanage lacks basic facilities children',
#  'mentally ill person wandering streets without care',
#  'rehabilitation center drug abuse victims functional',
#  'ngo providing aid underprivileged children facing legal hurdles',
#  'shelter home poor sanitation causing health issues',
#  'poor pregnant woman unable access free maternal care services',
#  'job guarantee scheme properly implemented village',
#  'remote tribal community receiving government aid',
#  'government official misusing welfare funds meant poor',
#  'disabled student denied scholarships benefits',
#  'welfare office takes long process benefit applications',
#  'helpline social welfare services always busy',
#  'website applying social benefits working properly',
#  'local community center reduced working hours',
#  'small town lacks awareness programs government welfare schemes',
#  'welfare department slow responding citizens’ queries',
#  'newly launched free meal program limited food options',
#  'community library funded welfare programs well-maintained',
#  'training program unemployed youth postponed',
#  'free skill development course lacks proper instructors',
#  'senior citizens’ recreational center insufficient seating',
#  'social worker assigned case frequently unavailable',
#  'government office provide proper facilities disabled visitors',
#  'free medical check-up camp well-organized',
#  'housing project poor facing minor delays',
#  'shelter home lacks adequate recreational activities children',
#  'beneficiary unable track status welfare application',
#  'public grievance redressal system slow respond',
#  'community garden elderly citizens maintained',
#  'free government transport service disabled people irregular timings',
#  'bridge collapsed alternative route needed relief workers',
#  'cyclone destroyed homes people shelter food drinking water',
#  'shortage drinking water cyclone still reserves',
#  'bridge collapsed alternative route needed relief workers',
#  'relief camp run food supplies people starving',
#  'large fire broken residential area need immediate evacuation assistance',
#  'large fire broken residential area need immediate evacuation assistance',
#  'tree fallen main road due heavy rain blocking traffic',
#  'landslide blocked exit routes villagers cut essential supplies',
#  'strong storm damaged houses people need temporary shelters',
#  'shortage drinking water cyclone still reserves',
#  'strong storm damaged houses people need temporary shelters',
#  'bridge collapsed alternative route needed relief workers',
#  'large fire broken residential area need immediate evacuation assistance',
#  'power lines due storm electricity three days',
#  'heavy rains flooded roads making transportation impossible',
#  'bridge collapsed alternative route needed relief workers',
#  'large fire broken residential area need immediate evacuation assistance',
#  'power lines due storm electricity three days',
#  'minor waterlogging issue locality storm',
#  'cyclone destroyed homes people shelter food drinking water',
#  'heavy rains flooded roads making transportation impossible',
#  'severe earthquake collapsed buildings many people trapped debris',
#  'bridge collapsed alternative route needed relief workers',
#  'cyclone destroyed homes people shelter food drinking water',
#  'minor waterlogging issue locality storm',
#  'tree fallen main road due heavy rain blocking traffic',
#  'power lines due storm electricity three days',
#  'power lines due storm electricity three days',
#  'bridge collapsed alternative route needed relief workers',
#  'relief camp run food supplies people starving',
#  'large fire broken residential area need immediate evacuation assistance',
#  'minor waterlogging issue locality storm',
#  'strong storm damaged houses people need temporary shelters',
#  'tree fallen main road due heavy rain blocking traffic',
#  'massive flood submerged entire village people stranded rooftops',
#  'landslide blocked exit routes villagers cut essential supplies',
#  'large fire broken residential area need immediate evacuation assistance',
#  'power lines due storm electricity three days',
#  'landslide blocked exit routes villagers cut essential supplies',
#  'severe earthquake collapsed buildings many people trapped debris',
#  'relief camp run food supplies people starving',
#  'strong storm damaged houses people need temporary shelters',
#  'minor waterlogging issue locality storm',
#  'strong storm damaged houses people need temporary shelters',
#  'cyclone destroyed homes people shelter food drinking water',
#  'minor waterlogging issue locality storm',
#  'shortage drinking water cyclone still reserves',
#  'houses suffered minor roof damage due strong winds',
#  'tree fallen main road due heavy rain blocking traffic',
#  'tree fallen main road due heavy rain blocking traffic',
#  'houses suffered minor roof damage due strong winds',
#  'local drainage system clogged due heavy rain causing inconvenience',
#  'houses suffered minor roof damage due strong winds',
#  'landslide blocked exit routes villagers cut essential supplies',
#  'houses suffered minor roof damage due strong winds',
#  'houses suffered minor roof damage due strong winds',
#  'tree fallen main road due heavy rain blocking traffic',
#  'massive flood submerged entire village people stranded rooftops',
#  'relief camp run food supplies people starving',
#  'large fire broken residential area need immediate evacuation assistance',
#  'large fire broken residential area need immediate evacuation assistance',
#  'landslide blocked exit routes villagers cut essential supplies',
#  'tree fallen main road due heavy rain blocking traffic',
#  'relief camp run food supplies people starving',
#  'relief camp run food supplies people starving',
#  'bridge collapsed alternative route needed relief workers',
#  'houses suffered minor roof damage due strong winds',
#  'local drainage system clogged due heavy rain causing inconvenience',
#  'landslide blocked exit routes villagers cut essential supplies',
#  'large fire broken residential area need immediate evacuation assistance',
#  'heavy rains flooded roads making transportation impossible',
#  'power lines due storm electricity three days',
#  'bridge collapsed alternative route needed relief workers',
#  'local drainage system clogged due heavy rain causing inconvenience',
#  'landslide blocked exit routes villagers cut essential supplies',
#  'strong storm damaged houses people need temporary shelters',
#  'power lines due storm electricity three days',
#  'local drainage system clogged due heavy rain causing inconvenience',
#  'large fire broken residential area need immediate evacuation assistance',
#  'heavy rains flooded roads making transportation impossible',
#  'shortage drinking water cyclone still reserves',
#  'relief camp run food supplies people starving',
#  'strong storm damaged houses people need temporary shelters',
#  'local drainage system clogged due heavy rain causing inconvenience',
#  'strong storm damaged houses people need temporary shelters',
#  'tree fallen main road due heavy rain blocking traffic',
#  'tree fallen main road due heavy rain blocking traffic',
#  'landslide blocked exit routes villagers cut essential supplies',
#  'tree fallen main road due heavy rain blocking traffic',
#  'shortage drinking water cyclone still reserves',
#  'strong storm damaged houses people need temporary shelters',
#  'cyclone destroyed homes people shelter food drinking water',
#  'shortage drinking water cyclone still reserves',
#  'massive flood submerged entire village people stranded rooftops',
#  'massive flood submerged entire village people stranded rooftops',
#  'tree fallen main road due heavy rain blocking traffic',
#  'houses suffered minor roof damage due strong winds',
#  'landslide blocked exit routes villagers cut essential supplies',
#  'shortage drinking water cyclone still reserves',
#  'government officer demanding bribe ₹50000 process land registration',
#  'bribes collected issuing driving licenses without tests',
#  'police officer refused file fir paid ₹10000',
#  'clerk demanding ₹500 approve birth certificate application',
#  'railway employee taking money confirm waiting list tickets',
#  'municipal worker demands small fee collect garbage regularly',
#  'local politicians involved embezzling funds road construction project',
#  "traffic police let people go without fines pay ₹200 'adjustment'",
#  'municipal officer extorting money shopkeepers unauthorized stalls',
#  'local politicians involved embezzling funds road construction project',
#  'teachers government school demanding extra money free education benefits',
#  'municipal officer extorting money shopkeepers unauthorized stalls',
#  'government officer demanding bribe ₹50000 process land registration',
#  'official delaying pension clearance unless pay ₹5000',
#  'official delaying pension clearance unless pay ₹5000',
#  'clerk demanding ₹500 approve birth certificate application',
#  'local politicians involved embezzling funds road construction project',
#  'teachers government school demanding extra money free education benefits',
#  "hospital staff demanding money release patient's medical reports",
#  'municipal officer extorting money shopkeepers unauthorized stalls',
#  'electricity board delaying meter installation bribe paid',
#  'clerk demanding ₹500 approve birth certificate application',
#  'police officer refused file fir paid ₹10000',
#  'electricity board delaying meter installation bribe paid',
#  'local politicians involved embezzling funds road construction project',
#  "traffic police let people go without fines pay ₹200 'adjustment'",
#  "traffic police let people go without fines pay ₹200 'adjustment'",
#  "traffic police let people go without fines pay ₹200 'adjustment'",
#  'electricity board delaying meter installation bribe paid',
#  'police officer refused file fir paid ₹10000',
#  'bank officer asking commission approve loan faster',
#  'bribes collected issuing driving licenses without tests',
#  'teachers government school demanding extra money free education benefits',
#  'local politicians involved embezzling funds road construction project',
#  "traffic police let people go without fines pay ₹200 'adjustment'",
#  'government officer demanding bribe ₹50000 process land registration',
#  "hospital staff demanding money release patient's medical reports",
#  'municipal worker demands small fee collect garbage regularly',
#  'official delaying pension clearance unless pay ₹5000',
#  'local politicians involved embezzling funds road construction project',
#  'official delaying pension clearance unless pay ₹5000',
#  'government officer demanding bribe ₹50000 process land registration',
#  'municipal officer extorting money shopkeepers unauthorized stalls',
#  'government employee misusing public funds meant flood relief',
#  'municipal officer extorting money shopkeepers unauthorized stalls',
#  'official delaying pension clearance unless pay ₹5000',
#  'police officer refused file fir paid ₹10000',
#  'bank officer asking commission approve loan faster',
#  'government employee misusing public funds meant flood relief',
#  'teachers government school demanding extra money free education benefits',
#  'government officer demanding bribe ₹50000 process land registration',
#  'official delaying pension clearance unless pay ₹5000',
#  'bank officer asking commission approve loan faster',
#  'bribes collected issuing driving licenses without tests',
#  "traffic police let people go without fines pay ₹200 'adjustment'",
#  'electricity board delaying meter installation bribe paid',
#  'official delaying pension clearance unless pay ₹5000',
#  'clerk demanding ₹500 approve birth certificate application',
#  'municipal officer extorting money shopkeepers unauthorized stalls',
#  "hospital staff demanding money release patient's medical reports",
#  'clerk demanding ₹500 approve birth certificate application',
#  'local politicians involved embezzling funds road construction project',
#  'teachers government school demanding extra money free education benefits',
#  'teachers government school demanding extra money free education benefits',
#  'municipal worker demands small fee collect garbage regularly',
#  'bribes collected issuing driving licenses without tests',
#  'government employee misusing public funds meant flood relief',
#  'government employee misusing public funds meant flood relief',
#  'municipal officer extorting money shopkeepers unauthorized stalls',
#  'police officer refused file fir paid ₹10000',
#  'electricity board delaying meter installation bribe paid',
#  'municipal worker demands small fee collect garbage regularly',
#  'teachers government school demanding extra money free education benefits',
#  'police officer refused file fir paid ₹10000',
#  'bribes collected issuing driving licenses without tests',
#  'railway employee taking money confirm waiting list tickets',
#  'teachers government school demanding extra money free education benefits',
#  'local politicians involved embezzling funds road construction project',
#  'bank officer asking commission approve loan faster',
#  "traffic police let people go without fines pay ₹200 'adjustment'",
#  'local politicians involved embezzling funds road construction project',
#  'electricity board delaying meter installation bribe paid',
#  "traffic police let people go without fines pay ₹200 'adjustment'",
#  'municipal officer extorting money shopkeepers unauthorized stalls',
#  'official delaying pension clearance unless pay ₹5000',
#  'railway employee taking money confirm waiting list tickets',
#  'municipal worker demands small fee collect garbage regularly',
#  'municipal worker demands small fee collect garbage regularly',
#  'official delaying pension clearance unless pay ₹5000',
#  'local politicians involved embezzling funds road construction project',
#  'local politicians involved embezzling funds road construction project',
#  "hospital staff demanding money release patient's medical reports",
#  'teachers government school demanding extra money free education benefits',
#  'government officer demanding bribe ₹50000 process land registration',
#  'government employee misusing public funds meant flood relief',
#  "traffic police let people go without fines pay ₹200 'adjustment'",
#  "traffic police let people go without fines pay ₹200 'adjustment'",
#  'clerk demanding ₹500 approve birth certificate application',
#  'teachers government school demanding extra money free education benefits',
#  'bank officer asking commission approve loan faster',
#  'prisoner tortured custody life danger',
#  'journalist kidnapped reporting government corruption',
#  'police brutality resulted severe injuries peaceful protestors',
#  'child labor camp discovered minors abused',
#  'woman illegally detained denied legal assistance',
#  'community forcefully evicted without notice rehabilitation',
#  'whistleblower received death threats exposing illegal activities',
#  'mentally ill person locked facility without proper care',
#  'family persecuted due religious beliefs',
#  'sexual assault survivor denied medical care legal support',
#  'prisoners denied proper food medical care',
#  'company forcing workers work inhumane conditions',
#  'transgender individual discriminated employment',
#  'disabled person denied access public facilities',
#  'senior citizen abandoned family needs assistance',
#  'tribal community denied access basic healthcare',
#  'refugee family mistreated government shelter',
#  'group students suspended raising concerns discrimination',
#  'authorities ignoring complaints bonded labor factory',
#  'person refused right legal representation court',
#  'media house unfairly censored reporting social issues',
#  'underprivileged child denied admission public school',
#  'police delaying registering fir caste-based violence case',
#  "company monitoring restricting employees' right privacy",
#  'journalist unfairly arrested exposing police misconduct',
#  'woman denied maternity benefits workplace',
#  'disabled student provided proper education facilities',
#  'community’s access drinking water restricted authorities',
#  'village cut communication due government negligence',
#  'local shop refusing serve people particular community',
#  'person facing discrimination renting house',
#  'hospital charging extra fees people lower economic backgrounds',
#  'private company conducting mandatory unpaid overtime',
#  'school forcing students follow particular dress code',
#  'public event wheelchair accessible',
#  'workplace grievance redressal system employee complaints',
#  'local transport system allowing physically challenged individuals easy access',
#  'library refusing membership economically weaker individuals',
#  'person asked unnecessary personal questions applying job',
#  'street performer harassed authorities valid reason',
#  'social media post human rights issues unfairly taken down',
#  'organization discriminating employees based political beliefs',
#  'hotel denied entry individual based appearance',
#  'government office provide information regional languages',
#  'protest disrupted even though prior approval',
#  "group allowed form legal workers' union",
#  'senior citizen denied pension due bureaucratic delays',
#  'historical site provide access differently-abled visitors',
#  'shop charging higher prices migrant workers',
#  'major sewage pipeline burst causing flooding residential areas',
#  'building construction collapsed trapping people inside',
#  'garbage dump caught fire causing toxic fumes',
#  'water supply pipeline burst leaving thousands without drinking water',
#  'main road caved due heavy rains creating dangerous sinkhole',
#  'dead body lying unattended public road hours',
#  'street completely submerged due clogged drainage blocking emergency vehicles',
#  'open electric pole wire sparking posing electrocution risk',
#  'tree fallen busy road blocking traffic completely',
#  'manhole open highway leading accidents',
#  'streetlights neighborhood non-functional weeks',
#  'garbage collection locality irregular month',
#  'playground meant children turned dumping ground',
#  'illegal encroachments footpaths making difficult pedestrians',
#  'public toilets extremely unhygienic conditions need maintenance',
#  'local park used illegal activities night',
#  'stray dogs increased area posing threat residents',
#  'water supplied colony foul smell may contaminated',
#  'recently constructed road developed deep cracks',
#  'construction debris dumped illegally open areas',
#  'community water tank leaking causing water wastage',
#  'public transport buses stopping designated bus stops',
#  'market area lacks proper waste disposal bins',
#  'illegal slaughterhouse operating residential area',
#  'several potholes bridge make unsafe vehicles',
#  'neighborhood lacks proper drainage system causing frequent waterlogging',
#  'government school building poor condition unsafe children',
#  'newly built community hall remains closed without notice',
#  'hospital waste dump emitting strong foul odor',
#  'street vendor market blocking emergency exits nearby buildings',
#  'open gym park broken equipment',
#  'street name boards faded unreadable',
#  'bus stop shelter broken roof',
#  'traffic signal buttons pedestrians working properly',
#  'recently painted wall defaced posters',
#  'civic workers sweeping streets instead twice day',
#  'public water tap leaking wasting water',
#  'community library irregular working hours',
#  'old water fountain park working',
#  'new parking area lacks proper signboards',
#  'benches public park broken need repair',
#  'mosquito fogging done regularly',
#  'speed breakers near school zone',
#  'several dustbins missing public garden',
#  'heritage building maintained properly',
#  'new public bicycle-sharing system functional',
#  'drainage cover slabs missing areas causing minor inconvenience',
#  'new clock tower city working',
#  'old public notice board filled outdated information',
#  'community hall lacks proper ventilation fans',
#  'bridge city developed large cracks posing collapse risk',
#  'major water pipeline burst causing flooding homes',
#  'broken electric transformer sparking continuously',
#  'uncollected garbage causing outbreak diseases slum area',
#  'drainage system failure led severe flooding hospital area',
#  'raw sewage flowing drinking water pipelines',
#  'sudden gas leak detected near residential area',
#  'open borewell poses danger children area',
#  'illegal industrial waste dump emitting toxic fumes',
#  'part flyover collapsed blocking busy road',
#  'local water supply inconsistent unreliable',
#  'government-funded school lacks proper sanitation facilities',
#  'open sewer causing bad smell health issues',
#  'major road city deep potholes leading frequent accidents',
#  'illegal posters banners blocking traffic signs',
#  'newly constructed road already developed cracks',
#  'street vendors occupied public parking spaces',
#  'community center misused private events',
#  'residential area without garbage collection weeks',
#  'encroachments public park reduced green spaces',
#  'several trees cut illegally affecting environment',
#  'public transport buses often overcrowded due poor scheduling',
#  'street sweepers maintaining market area',
#  'road repair project abandoned halfway',
#  'illegal dumping construction materials blocking footpaths',
#  'faulty drainage system causing foul smells near school',
#  'drinking water tanks public spaces cleaned regularly',
#  'illegal advertising banners obstructing footpaths',
#  'animal shelter run corporation lacks proper funding',
#  'community park used unauthorized commercial activities',
#  'public dustbin damaged replaced',
#  'waterlogging parks making inaccessible rain',
#  'public benches town square need repainting',
#  'local lake cleaned regularly',
#  'public notice board filled outdated information',
#  'drinking water facility park low water pressure',
#  'community playground lacks swings seesaws children',
#  'bus shelters cleaned regularly making unhygienic',
#  'city signboards faded text making navigation difficult',
#  'public restrooms lack sufficient soap toilet paper',
#  'city’s public fountains operational',
#  'open-air gym broken workout equipment',
#  'pedestrian bridge dirty slippery steps',
#  'streetlights flicker night causing inconvenience',
#  'city parks need benches elderly citizens',
#  'neighborhood lacks designated parking space bicycles',
#  'public gardens need better maintenance replanting flowers',
#  'new road sign placed incorrectly confusing drivers',
#  'dog park properly fenced allowing dogs wander off',
#  'city clock tower functioning properly']

# %%
data["Complaint"]=l

# %%
for i in data["Complaint"]:
    print(i)
# Out:
# ongoing robbery house please send help immediately
# witnessed kidnapping near central park
# serious accident happened people injured
# gang fight happening near street weapons
# house fire need emergency services now
# active shooter situation mall please respond urgently
# child missing last seen near school playground
# elderly person collapsed road unresponsive
# man harassing threatening people knife subway
# woman screaming help neighborhood fear domestic violence
# suspicious vehicle parked outside house hours
# neighbor keeps playing loud music late night disturbing everyone
# lost phone metro station tracked
# suspect someone dealing drugs near community park
# abandoned bag train station looks suspicious
# receiving scam calls claiming police department
# street light broken weeks making unsafe night
# found wallet street want return owner
# someone scratched car parking lot left without informing
# stray dog acting aggressively neighborhood might bite someone
# someone blocking driveway vehicle
# shopkeeper overcharging customers refusing give receipts
# people spitting public places despite ban
# potholes main road causing minor accidents
# street vendor operating without license front shop
# someone keeps throwing garbage front house every night
# local park maintained properly full litter
# kids bursting crackers odd hours disturbing residents
# people feeding pigeons balcony creating mess
# bikers performing stunts road causing inconvenience
# car parked no-parking zone blocking entrance building
# water leakage main road causing traffic congestion
# street performer creating nuisance loudspeakers near market
# person selling cigarettes minors outside school gate
# miscreants damaging public property subway station
# someone vandalized shop spray painting walls
# cyclist hit speeding car driver fled scene
# group teenagers drinking alcohol public park
# snake backyard need animal control support
# lost passport traveling need help report it
# streetlight flickering making unsafe pedestrians night
# landlord harassing refusing return deposit
# received fake currency note shop need report it
# delivery agent misbehaved refused deliver package
# major traffic jam due overturned truck highway
# strangers constantly loitering near house seems suspicious
# colleague threatening work fear safety
# atm area broken into suspect theft
# group people gambling open area near house
# people illegally cutting trees community park
# saw someone trying break parked car last night
# dead animal road causing foul smell hygiene issues
# wedding procession blocking road causing heavy traffic
# bike stolen parking lot need report it
# credit card details stolen unauthorized transactions made
# group people blocking road protest without permission
# friend gone missing last seen near railway station
# unknown number calling threatening repeatedly
# chemical spill near factory causing hazardous situation
# reckless driver almost hit pedestrians near school zone
# domestic helper suddenly disappeared cannot contact them
# people selling illegal firecrackers outside temple area
# man attempting break locked car parking lot
# illegal hoardings blocking visibility intersections
# beggar harassing commuters bus stop money
# suspect tenant running illegal business house
# power outage street thieves might take advantage
# vehicle tinted windows moving suspiciously around area
# children climbing under-construction building it’s unsafe
# local vendor dumping garbage nearby lake
# neighbor’s pet keeps trespassing property causing damage
# firecracker store caught fire spreading smoke area
# saw someone pickpocketing crowded train station
# man behaving indecently towards women metro
# individuals selling expired food products supermarket
# man following continuously feel unsafe
# package stolen doorstep away
# large pothole highway causing accidents
# someone ringing doorbell odd hours running away
# drainage system overflowing flooding streets
# house keys stolen along bag need assistance
# illegal sand mining happening near riverbed night
# truck over-speeding residential area risking lives
# person smoking inside hospital despite warnings
# neighbor burning trash causing smoke pollution
# bus drivers refusing stop designated stops
# found counterfeit notes cash given shop
# security guard shopping mall misbehaved customers
# group men trespassing private property near house
# tourist got lost jungle trek returned
# reports illegal arms trading near border
# relative taken hospital hit-and-run case
# domestic servant physically abused employer
# someone left unidentified package apartment lobby
# drone flying house repeatedly seems suspicious
# someone hacked bank account transferred money
# receiving death threats unknown person via email
# social media account hacked hacker posting illegal content
# cybercriminal blackmailing private photos
# major data breach company sensitive data leaked
# received email ransomware files locked
# child's online gaming account compromised hacker demanding money
# tricked installing malware device locked
# hacker gained access cloud storage deleted files
# someone created fake profile using identity scamming people
# received email threatening expose personal data unless pay ransom
# company's confidential data leaked dark web
# hackers taken control business website demanding money
# accidentally clicked fake paypal link account compromised
# hacker using email send phishing links contacts
# someone gained unauthorized access medical records
# hackers accessed webcam recording without knowledge
# received extortion email claiming access browsing history
# cryptocurrency wallet hacked funds stolen
# fraudulent loan taken name using stolen credentials
# received phishing email pretending bank
# fake e-commerce website scammed never delivered order
# someone impersonating social media messaging friends
# accidentally downloaded suspicious file computer slow
# fraudulent investment scheme advertised online
# credit card details stolen unauthorized transactions made
# keep receiving scam calls asking otp
# hacker tried access email able reset password
# stranger keeps sending inappropriate messages social media
# someone using wifi network without permission
# social media influencer promoting fraudulent crypto investment scheme
# scammer tricked sharing banking details call
# lost money online job scam asked advance fee
# someone created deepfake video shared online
# keep getting fake invoices unknown companies via email
# online gaming account hacked in-game purchases gone
# fraudster running fake giveaway collect personal details
# unknown device logged email without knowledge
# scammer created fake online dating profile tricked sending money
# software installed collecting personal data without consent
# someone stole domain name using fraudulent activities
# customer left false online review business damage reputation
# bot continuously spamming blog fake comments
# someone running lottery scam using name photos
# found website selling personal information
# keep getting random video calls strangers messaging apps
# fake charity website scamming people name donations
# hacker accessing work emails without authorization
# increase fake tech support calls area
# received email pretending police department asking money
# fraudulent online training program collecting personal information
# noticed someone trying access netflix streaming accounts
# fake travel agency scammed non-existent vacation packages
# bot network launching ddos attacks business website
# influencer running scam contest real prizes
# fake job recruiter asked pay training materials
# scammer tried register phone number different telecom provider
# keep getting spam emails despite blocking sender
# old social media account hacked longer use it
# got pop-up saying lottery click it
# ad blocker isn’t working properly browser
# online review company deleted without reason
# suspect someone using ai generate fake images me
# received promotional email unknown sender
# app downloaded asking unnecessary permissions
# someone created meme using photo without consent
# keep getting fake friend requests unknown people
# someone used email sign multiple random websites
# keep seeing fake product reviews online shopping sites
# website keeps auto-subscribing newsletter
# someone using profile picture without permission
# receiving many pop-up ads mobile browser
# website asked disable antivirus downloading software
# chatbot website giving misleading information
# social media platform allowing delete old posts
# gaming forum banned without valid reason
# noticed social media feed showing many ads
# email provider marking legitimate emails spam
# received fake job offer linkedin
# app installed draining phone battery abnormally fast
# saw website selling fake brand-name clothing items
# someone copying tweets reposting own
# online banking app logs frequently without reason
# saw scammer advertising fake digital marketing services
# mobile banking app showing incorrect transaction history
# weather app installed tracking location unnecessarily
# website visited recently sending excessive notifications
# facing domestic violence life danger
# sexually harassed traveling alone night
# man stalking every day near house
# received rape threats social media
# physically assaulted in-laws dowry demands
# husband threatening kill report domestic abuse
# drugged harassed party
# stranger following trying force car
# gang men harassing girls near college campus
# forcibly taken unknown location held will
# minor parents trying force marriage
# partner locked inside house refusing let leave
# saw girl forcefully dragged car group men
# groped crowded public place one helped
# someone blackmailing private pictures
# local goon harassing girls threatening acid attacks
# employer demanding sexual favors return salary
# group men harassing female colleagues daily
# found hidden camera hotel room
# stranger forcibly entered house tried assault me
# husband refuses give financial support children
# landlord making inappropriate advances toward me
# in-laws mentally torturing gave birth girl
# ex-boyfriend sharing false rumors online
# denied job woman
# shopkeeper harassed went shopping alone
# man keeps sending inappropriate messages despite blocking him
# colleague keeps invading personal space work
# facing constant pressure family quit job
# brother controls financial transactions won’t let independent
# man sending continuous messages despite warnings
# husband secretly recording phone conversations
# co-worker keeps making sexist jokes comments
# man tried take pictures without consent public
# stranger making obscene gestures every morning
# group boys neighborhood teases girls pass by
# friend abandoned husband refuses take responsibility
# social media account posting edited pictures me
# man threatened throw acid rejected proposal
# boss keeps making inappropriate remarks appearance
# husband’s family trying take away children me
# forced quit studies girl
# boy keeps spreading rumors college
# workplace complaint mechanism sexual harassment
# housemaid physically abused employer
# body-shamed relatives causing mental distress
# professor offering good grades exchange favors
# fake marriage proposal used scam take money
# daughter’s teacher behaving inappropriately her
# touched inappropriately stranger public transport
# colleague keeps forcing go despite refusals
# landlord refuses rent apartment single woman
# man stalking different social media platforms
# family forcefully keeping daughter-in-law locked home
# fiancé broke engagement refusing return belongings
# friend emotionally blackmailed staying toxic relationship
# constantly harassed boys coaching institute
# husband took huge loan name without consent
# man keeps staring public places making uncomfortable
# keep receiving fake marriage proposals unknown people
# husband doesn’t help household chores despite us working
# co-worker makes fun working mothers office
# parents don’t allow male friends
# neighborhood boy keeps whistling girls pass by
# feel unsafe walking alone night due lack streetlights
# faced gender discrimination restaurant dining alone
# boss refused approve maternity leave
# allowed go alone due family's conservative mindset
# family prefers brother educational opportunities
# man keeps catcalling every time walk past shop
# friends often dismiss safety concerns overreacting
# street vendor tried flirt shopping
# school proper sanitary facilities girls
# distant relative keeps making uncomfortable comments appearance
# group boys keeps following friends school
# apartment complex allow single women rent apartments
# cousin's husband often comments women stay home
# boy class keeps asking personal questions despite refusals
# neighborhood feel safe due lack police patrols
# female colleague denied promotion despite qualified
# forced wear traditional clothes family gathering
# male relatives control family decisions ignoring female opinions
# male passenger refused let sit reserved women's seat bus
# parents refused let take job societal pressure
# customer workplace keeps making sexist comments
# group men often block way near college harass girls
# boy tuition center keeps calling names
# friend asked inappropriate questions job interview
# major fire broken apartment complex people trapped inside
# factory near house caught fire explosions occurring
# gas cylinder exploded neighborhood fire spreading fast
# car caught fire busy market area people panicking
# fire broke school building students still inside
# high-rise building fire people stranded top floors
# huge fire hospital patients need immediate evacuation
# petrol pump caught fire spreading rapidly
# electric short circuit caused fire office building
# slum area caught fire many families risk
# bus full passengers caught fire highway
# chemical factory explosion triggered large-scale fire
# forest fire approaching residential areas
# train compartment caught fire traveling
# warehouse storing flammable materials burning
# fire lpg storage facility
# house colony caught fire due gas leak
# oil tanker overturned caught fire main road
# industrial unit dealing hazardous chemicals burning
# restaurant kitchen fire gone control
# burning smell smoke coming electrical transformer
# shop market caught fire one trapped inside
# fire broke garbage dump smoke unbearable
# tree caught fire due short circuit electrical wires
# minor fire broke atm cabin
# truck carrying chemicals emitting smoke
# small fire started parked vehicle
# fire godown partially controlled
# small explosion factory caused fire hazard
# air conditioning unit office started emitting smoke
# mobile tower caught fire thunderstorm
# sparks welding work ignited minor fire construction site
# power line fell started small fire residential area
# bonfire public event got control
# bakery caught fire due overheated oven
# fire started temple due unattended oil lamps
# unattended stove led minor kitchen fire
# firecrackers ignited small fire empty lot
# generator caught fire due overheating
# tent wedding function caught fire
# temporary festival stall caught fire nearby lamp
# bank's ups room emitting excessive heat smoke
# elevator machine room caught fire due overheating
# small explosion petrol station caused minor fire
# battery storage facility started emitting smoke
# firework manufacturing unit minor fire incident
# drone battery exploded started small fire
# restaurant's chimney caught fire due excessive grease buildup
# fire noticed inside mall’s food court kitchen
# laundromat dryer overheated caught fire
# home inverter battery exploded causing small fire
# illegal lpg refill center caught fire
# hotel room caught fire due unattended iron
# cotton warehouse caught fire spark
# cinema hall projection room fire incident
# scrap yard fire creating dense smoke
# fire car repair workshop spread nearby vehicles
# wooden furniture shop caught fire welding spark
# people burning dry leaves neighborhood creating smoke
# someone lighting fireworks restricted area
# local factory emitting smoke seems suspicious
# someone burning trash open field
# street vendor using illegal gas cylinder
# fire extinguisher office empty
# chimney bakery emitting excessive smoke
# transformer street making crackling noise
# barbecue park left unattended
# sparks noticed coming street lamp post
# garbage pile near house smoldering
# festival decoration caught fire immediately put out
# car’s exhaust pipe emitted flames momentarily
# someone using high-voltage electrical appliances without safety precautions
# candle left burning inside closed shop
# apartment’s emergency exit blocked making fire escape difficult
# neighbor stores flammable items garage
# power strip office overheating
# cigarette butt started minor burn grass
# heater left unattended house
# someone seen storing fireworks residential building
# fire alarm office working
# restaurant’s gas connection seems unsafe
# bonfire site properly extinguished
# small flare-up occurred mechanic's workshop controlled
# junkyard pile flammable waste
# emergency fire exit cinema hall locked
# bus driver smoking near fuel tank
# fire alarm school malfunctioning frequently
# illegal fireworks sale happening crowded market
# factory storing paint chemicals fire safety equipment
# vendor using open flame near petrol pump
# construction site unattended welding sparks
# neighbor frequently burns incense sticks near curtains
# temporary roadside food stall unsafe gas connections
# building construction lacks fire safety exits
# truck carrying flammable liquids seems poorly maintained
# fire safety drills conducted office
# grocery store selling expired contaminated baby food
# local pharmacy selling counterfeit medicines
# restaurant serving food visible mold insects
# gas cylinder delivered vendor leaking could cause explosion
# company running ponzi scheme scamming thousands investors
# hospital overcharging patients adding fake medical tests
# retailer illegally selling banned hazardous products consumers
# car dealer sold defective vehicle caused accident
# seller refusing replace faulty electrical appliance caught fire
# fraudulent loan company extorting customers illegal interest rates
# telecom provider charging hidden fees monthly bills
# online shopping platform delivered fake branded smartphone
# travel agency refusing refund canceled tickets despite policy
# retailer charging extra digital payments
# cosmetics brand falsely advertising product organic
# water purifier company providing promised free maintenance
# gym refused cancel membership keeps deducting monthly fees
# airline lost baggage providing compensation
# bank adding hidden charges savings account without notice
# hotel refused honor prepaid booking charged extra room
# home appliance brand delivered defective refrigerator refused repair
# company’s customer service refusing take responsibility product defect
# online seller sent empty package instead ordered item
# restaurant charged extra service fees without informing customers
# private school charging extra fees without justification
# insurance company refusing process valid claim
# ride-hailing service charged trip take
# local supermarket mislabeling imported goods locally made
# jewelry store sold fake gold refused take back
# health supplement company making false medical claims
# clothing store refused accept return even though policy allows it
# e-commerce website delayed order delivery week
# restaurant provide item paid takeaway order
# mobile network provider slow internet despite 5g claim
# supermarket scanner charged higher price displayed tag
# local bakery increased prices without updating menu
# courier service delayed parcel without updates
# cafe refused provide itemized bill
# home service provider complete work properly
# beauty salon overcharged service compared price list
# electronic store charged extra installation despite included
# cinema hall charging extra 3d glasses separately
# water bottle hotel costs 5 times mrp
# online food delivery app canceled order without reason
# clothing store displaying proper price tags
# local vendor selling fruits much higher prices market rate
# fast-food chain denied discount advertised
# furniture store delivered different color ordered
# mall parking lot charged double normal rate
# coffee shop charged extra takeaway packaging
# child abandoned near railway station crying help
# young girl physically abused guardians
# child locked inside house without food water several days
# witnessed man forcefully taking child inside vehicle
# minor girl kidnapped neighborhood
# child forced beg streets
# 10-year-old boy severely beaten employer shop
# toddler left alone car hours extreme heat
# minor forced child labor construction site
# underage girl married will
# newborn found abandoned near garbage dump
# children orphanage physically tortured caretakers
# child trafficked illegal activities
# disabled child left unattended bus station
# child locked inside storehouse crying help
# minor boy seen working hazardous chemical factory
# teenage girl harassed adult male repeatedly
# children local shelter home denied food medical care
# baby seen abandoned temple
# 12-year-old girl forced domestic labor
# schoolteacher verbally abusing students regularly
# child neighborhood left alone home daily parents work
# children daycare given proper meals
# shopkeeper making minors work beyond permissible hours
# young boy skipping school seen working tea stall
# group minors encouraged sell goods trains
# child showing signs neglect malnourishment
# minor forced work waiter restaurant
# girl missing colony days
# child found sleeping outside shop night
# group children living bridge without adult supervision
# neighbor frequently locks child outside house punishment
# children foster home complaining mistreated
# teacher publicly shames students affecting mental health
# child constantly seen begging near traffic signal
# minor boy working cleaner bus depot
# child neighborhood appears physically weak due poor nutrition
# foster family providing safe environment children
# mother threatening abandon child
# underage boy encouraged drive vehicle parents
# 14-year-old boy forced work bakery instead attending school
# children boarding school living unhygienic conditions
# teenager frequently involved theft needs rehabilitation support
# mentally challenged child taken care guardians
# young girl discouraged attending school
# minor addicted drugs due peer pressure
# child consistently missing school due family negligence
# 7-year-old boy found wandering alone market
# minor facing online bullying harassment
# family providing necessary medical care sick child
# foster home overcrowded children receiving proper attention
# child frequently seen inappropriately dressed shivering cold weather
# children local slum sent school
# teenage girl immense family pressure quit studies
# child disability receiving proper care home
# minor encouraged participate gambling activities
# young child left train station hours without supervision
# children made perform stunts roads money
# children locality playing road unsupervised
# school proper playground students
# child seen eating food dustbin
# 16-year-old given alcohol local shopkeepers
# children apartment playing near open drain
# boy continuously seen roaming around market school hours
# child found playing video games internet café day
# child frequently seen sleeping shop day
# group kids using abusive language harassing passersby
# minor boy riding motorbike without helmet
# teenagers using abandoned plot smoking spot
# child seen playing near open well
# neighbor regularly leaves child strangers
# school bus driver allowing children travel standing inside
# vendor selling expired snacks children
# 8-year-old seen carrying heavy items market
# minor found collecting money people pretending sick
# children playground left unattended till late night
# school proper drinking water facilities students
# children seen riding bicycles busy roads without safety gear
# boy caught shoplifting needs guidance instead punishment
# school inadequate toilet facilities girls
# teenagers frequently found fighting public parks
# child seen attempting cross busy highway alone
# small child left alone pet dog day
# children seen bursting firecrackers dangerous manner
# boy found frequently skipping school loitering around
# minor spending excessive time video gaming center
# local tuition center overcrowded students
# teenage girl pressurized work instead studying
# severe accident occurred main highway multiple injuries reported
# drunk driver speeding residential areas
# traffic signal working major intersection causing chaos
# truck overloaded hazardous chemicals overturned
# driver hit pedestrian fled scene
# school bus driving recklessly children onboard
# ambulance stuck traffic due illegal parking
# large pothole busy road causing vehicles lose control
# bridge developed visible cracks posing danger commuters
# speeding car driving wrong direction one-way road
# driver using fake number plate
# illegal street racing taking place city night
# commercial vehicle emitting excessive smoke causing pollution
# traffic officer asking bribe instead issuing ticket
# heavy vehicles entering no-entry zone trucks
# intersection heavily congested due improper traffic management
# bikers riding without helmets high-speed zone
# public buses stopping middle road pick passengers
# vehicles constantly jumping red lights particular junction
# ride-hailing cab dangerously overtaking vehicles
# auto-rickshaw driver refusing go meter overcharging
# illegal vendors occupied half road causing traffic blockage
# newly installed speed breaker unmarked causing sudden braking
# fuel tanker leaking highway causing fire hazard
# motorcyclists performing stunts public area
# cyclists using expressways meant motor vehicles
# pedestrian crossings near school making unsafe children
# flyover construction proper safety measures missing
# multiple auto-rickshaws parked illegally blocking busy road
# traffic signs missing newly developed road
# car parked no-parking zone near shopping mall
# minor fender-bender caused small traffic jam
# streetlight near traffic intersection functioning
# driver honking excessively despite traffic jam
# multiple vehicles parked haphazardly residential area
# zebra crossing faded making difficult pedestrians see
# truck blocking sidewalk parking it
# road construction project taking longer expected
# newly installed traffic signal unclear timings
# bus stop shelter broken leaving commuters exposed weather
# speed limit signs small visible night
# minor oil spill side road
# footbridge covered advertisements making signs hard read
# new roundabout confusing drivers unfamiliar area
# u-turn sign removed causing confusion commuters
# wrong-way driver caused brief delay corrected quickly
# temporary traffic diversion properly marked
# parking lot exit poorly designed leading unnecessary congestion
# pedestrian walkway partially blocked construction materials
# designated space cycle riders busy roads
# homeless shelter run food people starving
# elderly home severely understaffed leading neglect residents
# mentally challenged individual physically abused caretakers
# disabled person denied government benefits unlawfully
# child abandoned near railway station needs immediate help
# domestic violence survivor urgent need shelter
# community kitchen shut down leaving hundreds without food
# poor family evicted illegally living streets
# shelter women forcibly shut local authorities
# group elderly beggars harassed driven away public places
# widow receiving pension entitled to
# disabled individual facing discrimination government office
# senior citizen denied free medical assistance
# community welfare program discontinued without notice
# family living poverty line getting ration
# government hospital refusing treat homeless individuals
# women’s self-help group denied financial aid
# laborer denied wages government’s employment scheme
# local welfare office delaying applications disability benefits
# family affected natural disaster received promised relief
# government-run orphanage lacks basic facilities children
# mentally ill person wandering streets without care
# rehabilitation center drug abuse victims functional
# ngo providing aid underprivileged children facing legal hurdles
# shelter home poor sanitation causing health issues
# poor pregnant woman unable access free maternal care services
# job guarantee scheme properly implemented village
# remote tribal community receiving government aid
# government official misusing welfare funds meant poor
# disabled student denied scholarships benefits
# welfare office takes long process benefit applications
# helpline social welfare services always busy
# website applying social benefits working properly
# local community center reduced working hours
# small town lacks awareness programs government welfare schemes
# welfare department slow responding citizens’ queries
# newly launched free meal program limited food options
# community library funded welfare programs well-maintained
# training program unemployed youth postponed
# free skill development course lacks proper instructors
# senior citizens’ recreational center insufficient seating
# social worker assigned case frequently unavailable
# government office provide proper facilities disabled visitors
# free medical check-up camp well-organized
# housing project poor facing minor delays
# shelter home lacks adequate recreational activities children
# beneficiary unable track status welfare application
# public grievance redressal system slow respond
# community garden elderly citizens maintained
# free government transport service disabled people irregular timings
# bridge collapsed alternative route needed relief workers
# cyclone destroyed homes people shelter food drinking water
# shortage drinking water cyclone still reserves
# bridge collapsed alternative route needed relief workers
# relief camp run food supplies people starving
# large fire broken residential area need immediate evacuation assistance
# large fire broken residential area need immediate evacuation assistance
# tree fallen main road due heavy rain blocking traffic
# landslide blocked exit routes villagers cut essential supplies
# strong storm damaged houses people need temporary shelters
# shortage drinking water cyclone still reserves
# strong storm damaged houses people need temporary shelters
# bridge collapsed alternative route needed relief workers
# large fire broken residential area need immediate evacuation assistance
# power lines due storm electricity three days
# heavy rains flooded roads making transportation impossible
# bridge collapsed alternative route needed relief workers
# large fire broken residential area need immediate evacuation assistance
# power lines due storm electricity three days
# minor waterlogging issue locality storm
# cyclone destroyed homes people shelter food drinking water
# heavy rains flooded roads making transportation impossible
# severe earthquake collapsed buildings many people trapped debris
# bridge collapsed alternative route needed relief workers
# cyclone destroyed homes people shelter food drinking water
# minor waterlogging issue locality storm
# tree fallen main road due heavy rain blocking traffic
# power lines due storm electricity three days
# power lines due storm electricity three days
# bridge collapsed alternative route needed relief workers
# relief camp run food supplies people starving
# large fire broken residential area need immediate evacuation assistance
# minor waterlogging issue locality storm
# strong storm damaged houses people need temporary shelters
# tree fallen main road due heavy rain blocking traffic
# massive flood submerged entire village people stranded rooftops
# landslide blocked exit routes villagers cut essential supplies
# large fire broken residential area need immediate evacuation assistance
# power lines due storm electricity three days
# landslide blocked exit routes villagers cut essential supplies
# severe earthquake collapsed buildings many people trapped debris
# relief camp run food supplies people starving
# strong storm damaged houses people need temporary shelters
# minor waterlogging issue locality storm
# strong storm damaged houses people need temporary shelters
# cyclone destroyed homes people shelter food drinking water
# minor waterlogging issue locality storm
# shortage drinking water cyclone still reserves
# houses suffered minor roof damage due strong winds
# tree fallen main road due heavy rain blocking traffic
# tree fallen main road due heavy rain blocking traffic
# houses suffered minor roof damage due strong winds
# local drainage system clogged due heavy rain causing inconvenience
# houses suffered minor roof damage due strong winds
# landslide blocked exit routes villagers cut essential supplies
# houses suffered minor roof damage due strong winds
# houses suffered minor roof damage due strong winds
# tree fallen main road due heavy rain blocking traffic
# massive flood submerged entire village people stranded rooftops
# relief camp run food supplies people starving
# large fire broken residential area need immediate evacuation assistance
# large fire broken residential area need immediate evacuation assistance
# landslide blocked exit routes villagers cut essential supplies
# tree fallen main road due heavy rain blocking traffic
# relief camp run food supplies people starving
# relief camp run food supplies people starving
# bridge collapsed alternative route needed relief workers
# houses suffered minor roof damage due strong winds
# local drainage system clogged due heavy rain causing inconvenience
# landslide blocked exit routes villagers cut essential supplies
# large fire broken residential area need immediate evacuation assistance
# heavy rains flooded roads making transportation impossible
# power lines due storm electricity three days
# bridge collapsed alternative route needed relief workers
# local drainage system clogged due heavy rain causing inconvenience
# landslide blocked exit routes villagers cut essential supplies
# strong storm damaged houses people need temporary shelters
# power lines due storm electricity three days
# local drainage system clogged due heavy rain causing inconvenience
# large fire broken residential area need immediate evacuation assistance
# heavy rains flooded roads making transportation impossible
# shortage drinking water cyclone still reserves
# relief camp run food supplies people starving
# strong storm damaged houses people need temporary shelters
# local drainage system clogged due heavy rain causing inconvenience
# strong storm damaged houses people need temporary shelters
# tree fallen main road due heavy rain blocking traffic
# tree fallen main road due heavy rain blocking traffic
# landslide blocked exit routes villagers cut essential supplies
# tree fallen main road due heavy rain blocking traffic
# shortage drinking water cyclone still reserves
# strong storm damaged houses people need temporary shelters
# cyclone destroyed homes people shelter food drinking water
# shortage drinking water cyclone still reserves
# massive flood submerged entire village people stranded rooftops
# massive flood submerged entire village people stranded rooftops
# tree fallen main road due heavy rain blocking traffic
# houses suffered minor roof damage due strong winds
# landslide blocked exit routes villagers cut essential supplies
# shortage drinking water cyclone still reserves
# government officer demanding bribe ₹50000 process land registration
# bribes collected issuing driving licenses without tests
# police officer refused file fir paid ₹10000
# clerk demanding ₹500 approve birth certificate application
# railway employee taking money confirm waiting list tickets
# municipal worker demands small fee collect garbage regularly
# local politicians involved embezzling funds road construction project
# traffic police let people go without fines pay ₹200 'adjustment'
# municipal officer extorting money shopkeepers unauthorized stalls
# local politicians involved embezzling funds road construction project
# teachers government school demanding extra money free education benefits
# municipal officer extorting money shopkeepers unauthorized stalls
# government officer demanding bribe ₹50000 process land registration
# official delaying pension clearance unless pay ₹5000
# official delaying pension clearance unless pay ₹5000
# clerk demanding ₹500 approve birth certificate application
# local politicians involved embezzling funds road construction project
# teachers government school demanding extra money free education benefits
# hospital staff demanding money release patient's medical reports
# municipal officer extorting money shopkeepers unauthorized stalls
# electricity board delaying meter installation bribe paid
# clerk demanding ₹500 approve birth certificate application
# police officer refused file fir paid ₹10000
# electricity board delaying meter installation bribe paid
# local politicians involved embezzling funds road construction project
# traffic police let people go without fines pay ₹200 'adjustment'
# traffic police let people go without fines pay ₹200 'adjustment'
# traffic police let people go without fines pay ₹200 'adjustment'
# electricity board delaying meter installation bribe paid
# police officer refused file fir paid ₹10000
# bank officer asking commission approve loan faster
# bribes collected issuing driving licenses without tests
# teachers government school demanding extra money free education benefits
# local politicians involved embezzling funds road construction project
# traffic police let people go without fines pay ₹200 'adjustment'
# government officer demanding bribe ₹50000 process land registration
# hospital staff demanding money release patient's medical reports
# municipal worker demands small fee collect garbage regularly
# official delaying pension clearance unless pay ₹5000
# local politicians involved embezzling funds road construction project
# official delaying pension clearance unless pay ₹5000
# government officer demanding bribe ₹50000 process land registration
# municipal officer extorting money shopkeepers unauthorized stalls
# government employee misusing public funds meant flood relief
# municipal officer extorting money shopkeepers unauthorized stalls
# official delaying pension clearance unless pay ₹5000
# police officer refused file fir paid ₹10000
# bank officer asking commission approve loan faster
# government employee misusing public funds meant flood relief
# teachers government school demanding extra money free education benefits
# government officer demanding bribe ₹50000 process land registration
# official delaying pension clearance unless pay ₹5000
# bank officer asking commission approve loan faster
# bribes collected issuing driving licenses without tests
# traffic police let people go without fines pay ₹200 'adjustment'
# electricity board delaying meter installation bribe paid
# official delaying pension clearance unless pay ₹5000
# clerk demanding ₹500 approve birth certificate application
# municipal officer extorting money shopkeepers unauthorized stalls
# hospital staff demanding money release patient's medical reports
# clerk demanding ₹500 approve birth certificate application
# local politicians involved embezzling funds road construction project
# teachers government school demanding extra money free education benefits
# teachers government school demanding extra money free education benefits
# municipal worker demands small fee collect garbage regularly
# bribes collected issuing driving licenses without tests
# government employee misusing public funds meant flood relief
# government employee misusing public funds meant flood relief
# municipal officer extorting money shopkeepers unauthorized stalls
# police officer refused file fir paid ₹10000
# electricity board delaying meter installation bribe paid
# municipal worker demands small fee collect garbage regularly
# teachers government school demanding extra money free education benefits
# police officer refused file fir paid ₹10000
# bribes collected issuing driving licenses without tests
# railway employee taking money confirm waiting list tickets
# teachers government school demanding extra money free education benefits
# local politicians involved embezzling funds road construction project
# bank officer asking commission approve loan faster
# traffic police let people go without fines pay ₹200 'adjustment'
# local politicians involved embezzling funds road construction project
# electricity board delaying meter installation bribe paid
# traffic police let people go without fines pay ₹200 'adjustment'
# municipal officer extorting money shopkeepers unauthorized stalls
# official delaying pension clearance unless pay ₹5000
# railway employee taking money confirm waiting list tickets
# municipal worker demands small fee collect garbage regularly
# municipal worker demands small fee collect garbage regularly
# official delaying pension clearance unless pay ₹5000
# local politicians involved embezzling funds road construction project
# local politicians involved embezzling funds road construction project
# hospital staff demanding money release patient's medical reports
# teachers government school demanding extra money free education benefits
# government officer demanding bribe ₹50000 process land registration
# government employee misusing public funds meant flood relief
# traffic police let people go without fines pay ₹200 'adjustment'
# traffic police let people go without fines pay ₹200 'adjustment'
# clerk demanding ₹500 approve birth certificate application
# teachers government school demanding extra money free education benefits
# bank officer asking commission approve loan faster
# prisoner tortured custody life danger
# journalist kidnapped reporting government corruption
# police brutality resulted severe injuries peaceful protestors
# child labor camp discovered minors abused
# woman illegally detained denied legal assistance
# community forcefully evicted without notice rehabilitation
# whistleblower received death threats exposing illegal activities
# mentally ill person locked facility without proper care
# family persecuted due religious beliefs
# sexual assault survivor denied medical care legal support
# prisoners denied proper food medical care
# company forcing workers work inhumane conditions
# transgender individual discriminated employment
# disabled person denied access public facilities
# senior citizen abandoned family needs assistance
# tribal community denied access basic healthcare
# refugee family mistreated government shelter
# group students suspended raising concerns discrimination
# authorities ignoring complaints bonded labor factory
# person refused right legal representation court
# media house unfairly censored reporting social issues
# underprivileged child denied admission public school
# police delaying registering fir caste-based violence case
# company monitoring restricting employees' right privacy
# journalist unfairly arrested exposing police misconduct
# woman denied maternity benefits workplace
# disabled student provided proper education facilities
# community’s access drinking water restricted authorities
# village cut communication due government negligence
# local shop refusing serve people particular community
# person facing discrimination renting house
# hospital charging extra fees people lower economic backgrounds
# private company conducting mandatory unpaid overtime
# school forcing students follow particular dress code
# public event wheelchair accessible
# workplace grievance redressal system employee complaints
# local transport system allowing physically challenged individuals easy access
# library refusing membership economically weaker individuals
# person asked unnecessary personal questions applying job
# street performer harassed authorities valid reason
# social media post human rights issues unfairly taken down
# organization discriminating employees based political beliefs
# hotel denied entry individual based appearance
# government office provide information regional languages
# protest disrupted even though prior approval
# group allowed form legal workers' union
# senior citizen denied pension due bureaucratic delays
# historical site provide access differently-abled visitors
# shop charging higher prices migrant workers
# major sewage pipeline burst causing flooding residential areas
# building construction collapsed trapping people inside
# garbage dump caught fire causing toxic fumes
# water supply pipeline burst leaving thousands without drinking water
# main road caved due heavy rains creating dangerous sinkhole
# dead body lying unattended public road hours
# street completely submerged due clogged drainage blocking emergency vehicles
# open electric pole wire sparking posing electrocution risk
# tree fallen busy road blocking traffic completely
# manhole open highway leading accidents
# streetlights neighborhood non-functional weeks
# garbage collection locality irregular month
# playground meant children turned dumping ground
# illegal encroachments footpaths making difficult pedestrians
# public toilets extremely unhygienic conditions need maintenance
# local park used illegal activities night
# stray dogs increased area posing threat residents
# water supplied colony foul smell may contaminated
# recently constructed road developed deep cracks
# construction debris dumped illegally open areas
# community water tank leaking causing water wastage
# public transport buses stopping designated bus stops
# market area lacks proper waste disposal bins
# illegal slaughterhouse operating residential area
# several potholes bridge make unsafe vehicles
# neighborhood lacks proper drainage system causing frequent waterlogging
# government school building poor condition unsafe children
# newly built community hall remains closed without notice
# hospital waste dump emitting strong foul odor
# street vendor market blocking emergency exits nearby buildings
# open gym park broken equipment
# street name boards faded unreadable
# bus stop shelter broken roof
# traffic signal buttons pedestrians working properly
# recently painted wall defaced posters
# civic workers sweeping streets instead twice day
# public water tap leaking wasting water
# community library irregular working hours
# old water fountain park working
# new parking area lacks proper signboards
# benches public park broken need repair
# mosquito fogging done regularly
# speed breakers near school zone
# several dustbins missing public garden
# heritage building maintained properly
# new public bicycle-sharing system functional
# drainage cover slabs missing areas causing minor inconvenience
# new clock tower city working
# old public notice board filled outdated information
# community hall lacks proper ventilation fans
# bridge city developed large cracks posing collapse risk
# major water pipeline burst causing flooding homes
# broken electric transformer sparking continuously
# uncollected garbage causing outbreak diseases slum area
# drainage system failure led severe flooding hospital area
# raw sewage flowing drinking water pipelines
# sudden gas leak detected near residential area
# open borewell poses danger children area
# illegal industrial waste dump emitting toxic fumes
# part flyover collapsed blocking busy road
# local water supply inconsistent unreliable
# government-funded school lacks proper sanitation facilities
# open sewer causing bad smell health issues
# major road city deep potholes leading frequent accidents
# illegal posters banners blocking traffic signs
# newly constructed road already developed cracks
# street vendors occupied public parking spaces
# community center misused private events
# residential area without garbage collection weeks
# encroachments public park reduced green spaces
# several trees cut illegally affecting environment
# public transport buses often overcrowded due poor scheduling
# street sweepers maintaining market area
# road repair project abandoned halfway
# illegal dumping construction materials blocking footpaths
# faulty drainage system causing foul smells near school
# drinking water tanks public spaces cleaned regularly
# illegal advertising banners obstructing footpaths
# animal shelter run corporation lacks proper funding
# community park used unauthorized commercial activities
# public dustbin damaged replaced
# waterlogging parks making inaccessible rain
# public benches town square need repainting
# local lake cleaned regularly
# public notice board filled outdated information
# drinking water facility park low water pressure
# community playground lacks swings seesaws children
# bus shelters cleaned regularly making unhygienic
# city signboards faded text making navigation difficult
# public restrooms lack sufficient soap toilet paper
# city’s public fountains operational
# open-air gym broken workout equipment
# pedestrian bridge dirty slippery steps
# streetlights flicker night causing inconvenience
# city parks need benches elderly citizens
# neighborhood lacks designated parking space bicycles
# public gardens need better maintenance replanting flowers
# new road sign placed incorrectly confusing drivers
# dog park properly fenced allowing dogs wander off
# city clock tower functioning properly

# %%
lemmatizer= WordNetLemmatizer()
l=[]
for i in data["Complaint"]:
    words = word_tokenize(i)
    words = [lemmatizer.lemmatize(word) for word in words]
    l.append(" ".join(words))

# %%
vectorizer = TfidfVectorizer(max_features=5000)
x = vectorizer.fit_transform(l)

# %%
kmeans = KMeans(n_clusters=12, random_state=42, n_init=10)
data['cluster'] = kmeans.fit_predict(x)

# %%
terms = vectorizer.get_feature_names_out()
for i in range(12):
    words = [terms[ind] for ind in kmeans.cluster_centers_[i].argsort()[-10:]]
    print(f"Cluster {i}: {', '.join(words)}")
# Out:
# Cluster 0: minor, keep, school, near, caught, someone, public, without, fire, child
# Cluster 1: food, shelter, home, destroyed, still, shortage, reserve, cyclone, drinking, water
# Cluster 2: near, smell, storm, road, minor, waterlogging, locality, issue, open, causing
# Cluster 3: huge, fire, area, need, residential, broken, assistance, large, immediate, evacuation
# Cluster 4: clerk, school, extra, free, benefit, teacher, education, money, government, demanding
# Cluster 5: fee, demand, collect, shopkeeper, unauthorized, stall, extorting, money, officer, municipal
# Cluster 6: paid, board, meter, installation, storm, day, power, line, three, electricity
# Cluster 7: clogged, traffic, main, blocking, tree, fallen, due, road, rain, heavy
# Cluster 8: meant, misusing, road, local, construction, project, involved, politician, embezzling, fund
# Cluster 9: received, provide, department, officer, 10000, paid, fir, file, police, refused
# Cluster 10: camp, storm, run, starving, shelter, temporary, damaged, house, people, strong
# Cluster 11: go, pension, unless, official, clearance, 5000, 200, adjustment, fine, pay

# %%
department_mapping = {
    0: "Child Welfare Department",  # Words: child, school, minor, caught, fire  
    1: "Disaster Management",  # Words: cyclone, shelter, destroyed, food, drinking, water  
    2: "Municipal Corporation Department",  # Words: waterlogging, road, open, locality, smell  
    3: "Fire Department",  # Words: fire, evacuation, immediate, huge, residential  
    4: "Education Department",  # Words: school, teacher, education, money, government  
    5: "Consumer Protection Department",  # Words: shopkeeper, unauthorized, fee, extorting, municipal  
    6: "Electricity Department",  # Words: power, electricity, meter, installation, line  
    7: "Traffic Police Department",  # Words: traffic, road, blocking, tree, rain  
    8: "Anti-Corruption Bureau",  # Words: misusing, politician, project, embezzling, fund  
    9: "Police Department",  # Words: police, officer, department, file, FIR  
    10: "Social Welfare Department",  # Words: shelter, temporary, people, storm, camp  
    11: "Pension & Revenue Department"  # Words: pension, fine, official, pay, clearance  
}

# %%
list(data["Department"].unique())
# Out:
# ['Police Department',
#  'Cyber Crime Department',
#  'Women Helpline',
#  'Fire Department',
#  'Consumer Protection Department',
#  'Child Welfare Department',
#  'Traffic Police Department',
#  'Social Welfare Department',
#  'Disaster Management',
#  'Anti-Corruption Bureau',
#  'Human Right Department',
#  'Muncipal Coporation Department']

# %%
data['clustered_department'] = data['cluster'].map(department_mapping)

# %%
data["cluster"].value_counts()
# Out:
# cluster
# 0     699
# 2      49
# 10     28
# 9      26
# 4      26
# 7      23
# 5      22
# 1      20
# 11     19
# 8      17
# 6      13
# 3      11
# Name: count, dtype: int64

# %%
accuracy_score(data["Department"],data['clustered_department'])
# Out:
# 0.12172088142707241

# %%
dbscan = DBSCAN(eps=0.5, min_samples=5, metric="cosine")  # Adjust 'eps' based on dataset
data["dbcluster"] = dbscan.fit_predict(x)

# %%
department_mapping = {
    0: "Child Welfare Department",
    1: "Disaster Management",
    2: "Municipal Corporation Department",
    3: "Fire Department",
    4: "Education Department",
    5: "Consumer Protection Department",
    6: "Electricity Department",
    7: "Traffic Police Department",
    8: "Anti-Corruption Bureau",
    9: "Police Department",
    10: "Social Welfare Department",
    11: "Pension & Revenue Department"
}

# %%
data["dbdepartment"] = data["dbcluster"].map(department_mapping)

# %%
valid_clusters = data[data["cluster"] != -1]["cluster"]
valid_X = x[data["cluster"] != -1].toarray()

silhouette_avg = silhouette_score(valid_X, valid_clusters)
db_score = davies_bouldin_score(valid_X, valid_clusters)

print(f"Silhouette Score: {silhouette_avg:.2f}")
print(f"Davies-Bouldin Score: {db_score:.2f}")
# Out:
# Silhouette Score: 0.06
# Davies-Bouldin Score: 3.40
